# %% [markdown]
# # Quickstart
#
# ## Basic inference
# The easiest way to get started is by using the {class}`~fastdfe.base_inference.BaseInference` class which infers the DFE from a single pairs of SFSs, one neutral and one selected. In this example we create {class}`~fastdfe.spectrum.Spectrum` objects holding the SFS counts and pass it to BaseInference. Note that we are also required to specify the number of monomorphic sites (the last and first entries of the specified counts).

# %%
import fastdfe as fd

inf = fd.BaseInference(
    sfs_neut=fd.Spectrum([177130, 997, 441, 228, 156, 117, 114, 83, 105, 109, 652]),
    sfs_sel=fd.Spectrum([797939, 1329, 499, 265, 162, 104, 117, 90, 94, 119, 794])
)

# run inference
inf.run();
# Out:
# INFO:fastdfe.Discretization: Precomputing linear DFE-SFS transformation using midpoint integration.
# WARNING:fastdfe.Optimization: The MLE estimate is within 1% of the upper bound for {} and lower bound for {'all.p_b': 0, 'all.S_b': 0.0001}, but this might be nothing to worry about.
# INFO:fastdfe.BaseInference: Successfully finished optimization after 69 iterations and 510 function evaluations, obtaining a log-likelihood of -34.6321629044744.
# INFO:fastdfe.BaseInference: Inferred parameters: {'all.S_d': -9868.270989289615, 'all.b': 0.1508097745704915, 'all.p_b': 0.0, 'all.S_b': 0.0002191946595685579, 'all.eps': 0.006854664823870646}.

# %% [markdown]
# fastDFE uses maximum likelihood estimation (MLE) to find the DFE. By default, 10 local optimization runs are carried out to make sure a reasonably good global optimum has been bound. The DFE furthermore needs to parametrized where {class}`~fastdfe.parametrization.GammaExpParametrization` is used by default.

# %% [markdown]
# We can now plot the inferred DFE in discretized form (cf. {func}`~fastdfe.base_inference.BaseInference.plot_discretized`).

# %%
inf.plot_discretized();

# %% [markdown]
# We can also plot a comparison of the (selected) modelled and observed SFS (cf. {func}`~fastdfe.base_inference.BaseInference.plot_sfs_comparison`).

# %%
inf.plot_sfs_comparison();

# %% [markdown]
# ## Bootstrapping
#
# We can perform parametric bootstrapping (cf. {func}`~fastdfe.base_inference.BaseInference.bootstrap`)

# %%
inf.bootstrap(n_samples=100)

# redo the plotting
inf.plot_discretized();
# Out:
# Bootstrapping: 100%|██████████| 100/100 [00:00<00:00, 116.59it/s]

# %% [markdown]
# ## Serialization

# %%
# save the inference object to the file
# we can unserialized the inference by using BaseInference.from_file
inf.to_file("out/serialized.json")

# alternatively we can also save a summary to file
inf.get_summary().to_file("out/summary.json")
