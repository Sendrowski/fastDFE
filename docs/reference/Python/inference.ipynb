# %% [markdown]
# # DFE inference
# ## Estimating the deleterious DFE
# A short overview of basic DFE inference and bootstrapping is available in the {doc}`quickstart guide <../Python/quickstart>`. DFE inference requires one `neutral` and one `selected` SFS. In this example we use the bundled `Betula pendula` (silver birch) data. By default, bootstrapping is performed automatically, and the inference estimates only the deleterious component of the DFE using {class}`~fastdfe.parametrization.GammaExpParametrization`.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [4.8, 3.3]
plt.rcParams['xtick.labelsize'] = 9
plt.rcParams['ytick.labelsize'] = 9

np.set_printoptions(legacy='1.21')

import fastdfe as fd
fd.Settings.parallelize = False

# %%
import fastdfe as fd

sfs_neut=fd.Spectrum([177130, 997, 441, 228, 156, 117, 114, 83, 105, 109, 0])
sfs_sel=fd.Spectrum([797939, 1329, 499, 265, 162, 104, 117, 90, 94, 119, 0])

inf = fd.BaseInference(
    sfs_neut=sfs_neut,
    sfs_sel=sfs_sel
)

# run inference
inf.run()

inf.plot_discretized();
# Out:
# INFO:Discretization: Precomputing semidominant DFE-SFS transformation using midpoint integration.
# Discretization>Precomputing: 100%|██████████| 9/9 [00:00<00:00, 10.60it/s]
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 21.37it/s]
# INFO:BaseInference: Successfully finished optimization after 21 iterations and 108 function evaluations, obtaining a log-likelihood of -35.44
# INFO:BaseInference: Inferred parameters: {all.S_d: -3.389e+04, all.b: 0.1305, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 3.307, all.b: 1.389e-06, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 5.008e-09}.
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:03<00:00, 25.90it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.862e+04, all.b: 0.02186, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 5.922, i_best_run: 0.5, likelihoods_std: 0.0387}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.004716.

# %% [markdown]
# It is always good practice to check the variability of estimates across optimization runs to ensure stability. Here, both the standard deviations across initial runs and across runs within each bootstrap sample are low, indicating stable estimates. Individual runs and bootstrap results can be inspected in the corresponding dataframes (cf. {attr}`~fastdfe.base_inference.BaseInference.runs` and {attr}`~fastdfe.base_inference.BaseInference.bootstraps`).

# %%
inf.runs.select_dtypes('number')
# Out:
#         all.S_d     all.b  all.p_b  all.S_b  all.eps  all.h  likelihood
# 0 -33900.123908  0.130542      0.0      1.0      0.0    0.5  -35.437968
# 1 -33893.293634  0.130545      0.0      1.0      0.0    0.5  -35.437968
# 2 -33892.180405  0.130545      0.0      1.0      0.0    0.5  -35.437968
# 3 -33893.318148  0.130545      0.0      1.0      0.0    0.5  -35.437968
# 4 -33893.884802  0.130544      0.0      1.0      0.0    0.5  -35.437968
# 5 -33897.863158  0.130543      0.0      1.0      0.0    0.5  -35.437968
# 6 -33896.747907  0.130543      0.0      1.0      0.0    0.5  -35.437968
# 7 -33902.407293  0.130541      0.0      1.0      0.0    0.5  -35.437969
# 8 -33894.455210  0.130544      0.0      1.0      0.0    0.5  -35.437968
# 9 -33895.374453  0.130544      0.0      1.0      0.0    0.5  -35.437968

# %%
inf.bootstraps.select_dtypes('number')
# Out:
#               S_d         b  p_b  S_b  eps    h  likelihood  i_best_run  \
# 0  -100000.000000  0.115271  0.0  1.0  0.0  0.5  -48.666719           0
# 1   -23098.881789  0.132768  0.0  1.0  0.0  0.5  -39.454392           1
# 2   -30896.418232  0.126525  0.0  1.0  0.0  0.5  -44.116520           0
# 3  -100000.000000  0.117041  0.0  1.0  0.0  0.5  -40.332661           0
# 4   -27265.178738  0.134771  0.0  1.0  0.0  0.5  -38.642477           1
# ..            ...       ...  ...  ...  ...  ...         ...         ...
# 95  -59602.611842  0.121742  0.0  1.0  0.0  0.5  -38.589821           0
# 96   -3523.466018  0.172044  0.0  1.0  0.0  0.5  -33.468514           1
# 97 -100000.000000  0.114860  0.0  1.0  0.0  0.5  -44.168668           1
# 98   -5645.566005  0.160873  0.0  1.0  0.0  0.5  -34.451027           1
# 99  -12975.675104  0.146722  0.0  1.0  0.0  0.5  -36.749411           1
#
#     likelihoods_std  alpha
# 0      4.718004e-10    0.0
# 1      3.549587e-10    0.0
# 2      7.421193e-10    0.0
# 3      1.421085e-13    0.0
# 4      6.879191e-10    0.0
# ..              ...    ...
# 95     2.388276e-10    0.0
# 96     1.900275e-10    0.0
# 97     3.817803e-01    0.0
# 98     2.424940e-10    0.0
# 99     1.604491e-09    0.0
#
# [100 rows x 10 columns]

# %% [markdown]
# We can also plot the parameter distributions across bootstrap samples to visualize uncertainty. We see that the mean strength of deleterious selection `S_d` often reaches the lower bounds of `-1e5`. Perhaps a different DFE parameterization or a more complex DFE model would be more appropriate here. It should also be noted that the spectra used in this example are far from exemplary, as they contain few SNPs and have a small sample size.

# %%
inf.bootstraps[['S_d', 'b']].hist(figsize=(6, 2));

# %% [markdown]
# We can also inspect how parameters covary.

# %%
inf.bootstraps.assign(S_d=inf.bootstraps.S_d.abs()).plot.hexbin('S_d', 'b', xscale='log', gridsize=15);

# %% [markdown]
# We observe a slight dependence between the mean `S_d` and the shape parameter `b` of {class}`~fastdfe.parametrization.GammaExpParametrization`. This is because a large fraction of moderately deleterious mutations and a smaller fraction of strongly deleterious mutations can leave a similar signal in the SFS. Spectra with larger sample sizes might facilitate disentangling the two.

# %% [markdown]
# ## Estimating beneficial effects
# Parameters can be held fixed during maximum-likelihood optimization, and this was already done internally in the example above. By default, fastDFE infers only the deleterious DFE, fixes the ancestral-allele misidentification rate `eps`, and assumes semi-dominant mutations (`h = 0.5`) (see {attr}`~fastdfe.base_inference.BaseInference.fixed_params`). Here, we estimate the full DFE, allowing for beneficial mutations by letting the parameters `S_b` and `p_b` of {class}`~fastdfe.parametrization.GammaExpParametrization` vary, while `eps` and `h` remain fixed. The fixed parameters are wrapped in a dictionary under the key `all`, meaning these settings apply to all SFS types, which matters when running joint inference (cf. {class}`~fastdfe.joint_inference.JointInference`).

# %%
# create inference object
inf = fd.BaseInference(
    sfs_neut=sfs_neut,
    sfs_sel=sfs_sel,
    fixed_params=dict(all=dict(eps=0, h=0.5))
)

# run inference
inf.run()

inf.plot_discretized();
# Out:
# INFO:Discretization: Precomputing semidominant DFE-SFS transformation using midpoint integration.
# Discretization>Precomputing: 100%|██████████| 9/9 [00:00<00:00, 10.50it/s]
# INFO:Optimization: Optimizing 4 parameters: [all.S_b, all.S_d, all.b, all.p_b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 10.48it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {all.S_b: (0.0001, 100, 100)} and lower bound for {all.p_b: (0, 0.0043679086, 0.5)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 74 iterations and 495 function evaluations, obtaining a log-likelihood of -34.73
# INFO:BaseInference: Inferred parameters: {all.S_d: -9823, all.b: 0.1549, all.p_b: 0.004368, all.S_b: 100, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 4343, all.b: 0.1275, all.p_b: 0.09134, all.S_b: 51.64, all.eps: 0, all.h: 0, likelihood: 0.24}.
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:13<00:00,  7.15it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.389e+04, all.b: 2.144, all.p_b: 0.08744, all.S_b: 49.44, all.eps: 0, all.h: 0, likelihood: 5.767, i_best_run: 0.4902, likelihoods_std: 0.5596}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.3076.

# %% [markdown]
# The inferred full DFE shows substantial uncertainty, which is expected with a small sample and few SNPs. This is most pronounced for the [-1, 0] and [0, 1] bins, in which mutations are effectively neutral and provide little signal. Adjusting the discretization intervals can help reveal the structure more clearly (cf. {func}`~fastdfe.base_inference.BaseInference.plot_discretized`).

# %%
inf.plot_discretized(intervals=[-np.inf, -100, -10, -1, 1, np.inf]);

# %% [markdown]
# ## Ancestral-allele misidentification
# We can also adjust for ancestral-allele misidentification by letting parameter `eps` vary. `eps` is the probability that an allele is misidentified as derived when it is actually ancestral, and vice versa (cf. {func}`~fastdfe.spectrum.Spectrum.misidentify`). This can correct biases to the SFS caused by mis-polarization, but `eps` is somewhat difficult to interpret because it is applied simultaneously to both the neutral and selected SFS. In addition, `eps` assumes the fraction of ancestral misidentification to be constant across site classes, but in practise errors may differ across classes. Nevertheless, below, we infer the full DFE while allowing `eps` to vary.

# %%
inf = fd.BaseInference(
    sfs_neut=sfs_neut,
    sfs_sel=sfs_sel,
    fixed_params=dict(all=dict(h=0.5))
)

inf.run()
# Out:
# INFO:Discretization: Precomputing semidominant DFE-SFS transformation using midpoint integration.
# Discretization>Precomputing: 100%|██████████| 9/9 [00:00<00:00, 10.59it/s]
# INFO:Optimization: Optimizing 5 parameters: [all.eps, all.b, all.p_b, all.S_d, all.S_b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:01<00:00,  8.53it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.p_b: (0, 0, 0.5)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 34 iterations and 258 function evaluations, obtaining a log-likelihood of -34.63
# INFO:BaseInference: Inferred parameters: {all.S_d: -1.004e+04, all.b: 0.1508, all.p_b: 0, all.S_b: 0.0004628, all.eps: 0.006855, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.466, all.b: 2.814e-06, all.p_b: 0, all.S_b: 0.05387, all.eps: 4.049e-07, all.h: 0, likelihood: 1.553e-08}.
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:18<00:00,  5.30it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.37e+04, all.b: 2.142, all.p_b: 0.09036, all.S_b: 0.4023, all.eps: 0.00673, all.h: 0, likelihood: 5.635, i_best_run: 0.4824, likelihoods_std: 0.156}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.02306.

# %%
inf.bootstraps[['eps']].hist(figsize=(4, 2));

# %% [markdown]
# `eps` is estimated to be rather low, indicating that ancestral-allele misidentification is not a major issue in this dataset, or, at least, that including it that does not significantly improve the model fit. We can also check this in a more principled way by performing a likelihood-ratio test as done below.

# %% [markdown]
# ## Nested model comparison
# We can automatically check for the significance of include ancestral-allele misidentification and beneficial fitness affects using likelihood ratio tests. This is done with {func}`~fastdfe.base_inference.BaseInference.plot_nested_models`. The LRTs are performed by comparing the likelihood of the inferred DFE to the likelihood of a nested model where some parameters are held fixed. Alternatively, we can use {func}`~fastdfe.base_inference.BaseInference.compare_nested` to directly compare two nested models.

# %%
# set logging level to warning to avoid cluttering
fd.logger.setLevel('WARNING')

inf.plot_nested_models()

fd.logger.setLevel('INFO')
# Out:
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:01<00:00,  8.69it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {all.S_b: (0.0001, 100, 100)} and lower bound for {all.p_b: (0, 0.004367919, 0.5)} [(lower, value, upper)], but this might be nothing to worry about.
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:14<00:00,  7.11it/s]
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:01<00:00,  8.03it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.p_b: (0, 0, 0.5)} [(lower, value, upper)], but this might be nothing to worry about.
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:18<00:00,  5.46it/s]
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 40.05it/s]
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:03<00:00, 26.61it/s]
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 26.84it/s]
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:05<00:00, 17.04it/s]

# %% [markdown]
# Including ancestral allele misidentification appears to improve the fit significantly when modelling the deleterious DFE, although usually the deleterious DFE is far less sensitive to polarization error than a beneficial one.

# %% [markdown]
# ## Dominance effects
# By default, fastDFE assumes semi-dominance (`h = 0.5`), which is more or less appropriate depending on the organism and type of mutations considered. We can change the dominance coefficient to a different value of `h` if we believe this is more appropriate. However, in practise, `h` often depends on the strength of selection, with more deleterious mutations being more recessive. To model this, we can specify a callback function that returns the dominance coefficient as a function of the selection coefficient `S = 4Ne`.
#
# In the example below, we use an exponential decay: `h` is about 0.4 for neutral mutations and approaches 0 for strongly deleterious ones. The callback also receives `h` itself, allowing the dominance function to be parametrized and optimized; for simplicity, this parameter is still called `h`. Its bounds can be set via {attr}`~fastdfe.base_inference.BaseInference.bounds`.

# %%
import numpy as np

inf = fd.BaseInference(
    sfs_neut=sfs_neut,
    sfs_sel=sfs_sel,
    fixed_params=dict(all=dict(eps=0, h=0, p_b=0, S_b=1)),
    h_callback=lambda h, S: 0.4 * np.exp(-0.1 * abs(S))
)

inf.run()
# Out:
# INFO:Discretization: Precomputing DFE-SFS transformation for fixed dominance coefficients.
# Discretization>Precomputing: 100%|██████████| 1809/1809 [00:29<00:00, 61.47it/s]
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 61.96it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# WARNING:BaseInference: The L1 residual comparing the modelled and observed SFS is rather large: `norm(sfs_modelled - sfs_observed, 1) / sfs_observed` = 0.157. This may indicate that the model does not fit the data well.
# INFO:BaseInference: Successfully finished optimization after 9 iterations and 39 function evaluations, obtaining a log-likelihood of -74.33
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1401, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 0, all.b: 2.042e-09, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 1.108e-12}.
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:02<00:00, 44.60it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 0, all.b: 0.003201, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 15.08, i_best_run: 0.5009, likelihoods_std: 22.38}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 2.288.

# %% [markdown]
# Let's compare the inferred DFE under this dominance relationship to that of the default semi-dominant model.

# %%
inf2 = fd.BaseInference(
    sfs_neut=sfs_neut,
    sfs_sel=sfs_sel,
    fixed_params=dict(all=dict(eps=0, h=0.5, p_b=0, S_b=1))
)

inf2.run()
# Out:
# INFO:Discretization: Precomputing semidominant DFE-SFS transformation using midpoint integration.
# Discretization>Precomputing: 100%|██████████| 9/9 [00:00<00:00, 10.62it/s]
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 41.48it/s]
# INFO:BaseInference: Successfully finished optimization after 21 iterations and 108 function evaluations, obtaining a log-likelihood of -35.44
# INFO:BaseInference: Inferred parameters: {all.S_d: -3.389e+04, all.b: 0.1305, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 3.307, all.b: 1.389e-06, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 5.008e-09}.
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:03<00:00, 25.99it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.862e+04, all.b: 0.02186, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 5.922, i_best_run: 0.5, likelihoods_std: 0.0387}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.004716.

# %%
fd.DFE.plot_many([inf.get_dfe(), inf2.get_dfe()], labels=['partly recessive', 'h=0.5']);

# %% [markdown]
# We see that assuming mutations are partly recessive leads to a more deleterious inferred DFE since stronger selection is necessary to remove a similar amount of recessive mutations.
#
# We can also let `h` vary when inferring the DFE (cf. the {doc}`simulation guide <../Python/simulation>`).

# %% [markdown]
# ## Folded inference
# To infer the DFE from a folded SFS, simply pass folded spectra to {class}`~fastdfe.base_inference.BaseInference`. Folded inference is performed whenever the spectra are folded, i.e., when all entries where the derived allele is the major allele are zero. Folded spectra contain little information on beneficial mutations so we only infer the deleterious part of the DFE here.

# %%
import matplotlib.pyplot as plt
import numpy as np

# create inference object
inf = fd.BaseInference(
    sfs_neut=sfs_neut.fold(),
    sfs_sel=sfs_sel.fold()
)

# run inference
inf.run()

# plot the inferred DFE and the SFS comparison
ax1, ax2 = plt.subplots(ncols=2, figsize=(7, 3.2))[1]

inf.plot_discretized(ax=ax1, show=False, intervals=np.array([-np.inf, -100, -10, -1, 0]))
inf.plot_sfs_comparison(ax=ax2, show=False)

plt.tight_layout()
plt.show()
# Out:
# INFO:Discretization: Precomputing semidominant DFE-SFS transformation using midpoint integration.
# Discretization>Precomputing: 100%|██████████| 9/9 [00:00<00:00, 10.54it/s]
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 39.00it/s]
# INFO:BaseInference: Successfully finished optimization after 21 iterations and 81 function evaluations, obtaining a log-likelihood of -21.58
# INFO:BaseInference: Inferred parameters: {all.S_d: -1.558e+04, all.b: 0.1464, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 0.8027, all.b: 9.344e-07, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 2.349e-09}.
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:04<00:00, 23.73it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.881e+04, all.b: 0.02691, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 4.188, i_best_run: 0.5016, likelihoods_std: 0.01161}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.001161.

# %% [markdown]
# ## Serialization
# Inference objects can be serialized to JSON files for later use (cf. {func}`~fastdfe.base_inference.BaseInference.to_file`).

# %%
# save the inference object to a file
# we can unserialized the inference by using BaseInference.from_file
inf.to_file("out/serialized.json")

# we can also save a short summary to fa ile
inf.get_summary().to_file("out/summary.json")

# %% [markdown]
# ## Joint inference
# fastDFE supports joint inference of several SFS types, where any parameters can be shared between types. In this example, we create a {class}`~fastdfe.joint_inference.JointInference` object with two types, where we share ``eps``, the rate of ancestral misidentification and ``S_d``, the mean selection coefficient for deleterious mutations (cf. {class}`~fastdfe.parametrization.GammaExpParametrization`). For more complex stratifications, see the {class}`~fastdfe.parser.Parser`) module.

# %%
# neutral SFS for two types
sfs_neut = fd.Spectra(dict(
    pendula=[177130, 997, 441, 228, 156, 117, 114, 83, 105, 109, 0],
    pubescens=[172528, 3612, 1359, 790, 584, 427, 325, 234, 166, 76, 31]
))

# selected SFS for two types
sfs_sel = fd.Spectra(dict(
    pendula=[797939, 1329, 499, 265, 162, 104, 117, 90, 94, 119, 0],
    pubescens=[791106, 5326, 1741, 1005, 756, 546, 416, 294, 177, 104, 41]
))

# create inference object
inf = fd.JointInference(
    sfs_neut=sfs_neut,
    sfs_sel=sfs_sel,
    shared_params=[fd.SharedParams(types=["pendula", "pubescens"], params=["S_d"])]
)

# run inference
inf.run();
# Out:
# INFO:JointInference: Using shared parameters [SharedParams(params=['S_d'], types=['pendula', 'pubescens'])].
# INFO:JointInference: Including covariates: {}.
# INFO:JointInference: Running marginal inference for type 'all'.
# INFO:Discretization: Precomputing semidominant DFE-SFS transformation using midpoint integration.
# Discretization>Precomputing: 100%|██████████| 9/9 [00:00<00:00, 10.17it/s]
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 44.00it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 25 iterations and 99 function evaluations, obtaining a log-likelihood of -45.09
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1066, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 0, all.b: 1.186e-09, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 8.022e-12}.
# INFO:JointInference: Running marginal inferences for types ['pendula', 'pubescens'].
# INFO:JointInference: Running marginal inference for type 'pendula'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 36.87it/s]
# INFO:BaseInference: Successfully finished optimization after 21 iterations and 108 function evaluations, obtaining a log-likelihood of -35.44
# INFO:BaseInference: Inferred parameters: {all.S_d: -3.389e+04, all.b: 0.1305, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 3.042, all.b: 1.273e-06, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 4.708e-09}.
# INFO:JointInference: Running marginal inference for type 'pubescens'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 44.20it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 10 iterations and 60 function evaluations, obtaining a log-likelihood of -43.81
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1035, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 0, all.b: 1.869e-09, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 4.431e-12}.
# INFO:JointInference: Running joint inference for types ['pendula', 'pubescens'].
# INFO:Optimization: Optimizing 3 parameters: [pendula.b, pendula:pubescens.S_d, pubescens.b].
# JointInference>Performing joint inference: 100%|██████████| 10/10 [00:00<00:00, 14.57it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {pendula:pubescens.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:JointInference: Successfully finished optimization after 26 iterations and 224 function evaluations, obtaining a log-likelihood of -79.46
# INFO:JointInference: Inferred parameters: {pendula.b: 0.1168, pendula.p_b: 0, pendula.S_b: 1, pendula.eps: 0, pendula.h: 0.5, pendula.S_d: -1e+05, pubescens.b: 0.1035, pubescens.p_b: 0, pubescens.S_b: 1, pubescens.eps: 0, pubescens.h: 0.5, pubescens.S_d: -1e+05}.
# INFO:JointInference: Standard deviations across runs: {pendula.b: 2.273e-09, pendula.p_b: 0, pendula.S_b: 0, pendula.eps: 0, pendula.h: 0, pubescens.b: 1.681e-09, pubescens.p_b: 0, pubescens.S_b: 0, pubescens.eps: 0, pubescens.h: 0, pendula:pubescens.S_d: 0, likelihood: 5.599e-12}.
# INFO:JointInference: Bootstrapping type 'all'.
# BaseInference>Bootstrapping 'all' (2 runs each): 100%|██████████| 100/100 [00:03<00:00, 31.24it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 2.664e+04, all.b: 0.007316, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 7.53, i_best_run: 0.5024, likelihoods_std: 0.001601}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.0002858.
# INFO:JointInference: Bootstrapping type 'pendula'.
# BaseInference>Bootstrapping 'pendula' (2 runs each): 100%|██████████| 100/100 [00:03<00:00, 25.57it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.862e+04, all.b: 0.02186, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 5.922, i_best_run: 0.5, likelihoods_std: 0.0387}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.004716.
# INFO:JointInference: Bootstrapping type 'pubescens'.
# BaseInference>Bootstrapping 'pubescens' (2 runs each): 100%|██████████| 100/100 [00:03<00:00, 32.44it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 2.121e+04, all.b: 0.005512, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 7.557, i_best_run: 0.5016, likelihoods_std: 0.02267}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.002306.
# JointInference>Bootstrapping joint inference (2 runs each): 100%|██████████| 100/100 [00:09<00:00, 11.09it/s]
# INFO:JointInference: Standard deviations across bootstraps: {pendula.b: 0.006864, pendula.p_b: 0, pendula.S_b: 0, pendula.eps: 0, pendula.h: 0, pendula.S_d: 2.49e+04, pubescens.b: 0.005859, pubescens.p_b: 0, pubescens.S_b: 0, pubescens.eps: 0, pubescens.h: 0, pubescens.S_d: 2.49e+04, likelihood: 9.248, i_best_run: 0.4976, likelihoods_std: 67.69}.
# INFO:JointInference: Average standard deviation of likelihoods across runs within bootstrap samples: 6.769.

# %% [markdown]
# {class}`~fastdfe.joint_inference.JointInference` both runs the joint inference and marginal inference where each type is inferred separately. To see this better we can plot the inferred parameters for the different inference types.

# %%
inf.plot_inferred_parameters();

# %% [markdown]
# ``marginal.pendula`` and ``marginal.pubescens`` are the marginal inferences for the respective type. ``marginal.all`` is the marginal inference obtaining by adding up the spectra of all types. ``joint.pendula`` and ``join.pubescens`` are the joint inferences for the respective type. We can see that ``eps`` and ``S_d`` are indeed shared between the two. The parameter ``alpha`` in the plot denotes the proportion of beneficial non-synonymous substitutions. Each marginal inference is a {class}`~fastdfe.base_inference.BaseInference` object itself and can be accessed via ``inf.marginal_inferences[type]``.
#
# We can now also investigate to what extent the inferred DFEs differ:

# %%
inf.plot_discretized();

# %% [markdown]
# ### Model comparison
# We can obtain information about the goodness of fit achieved by sharing the parameter by performing a likelihood ratio test (cf. {func}`~fastdfe.joint_inference.JointInference.perform_lrt_shared`). This compares the likelihood of the joint inference with the product of the marginal likelihoods.

# %%
inf.perform_lrt_shared()
# Out:
# INFO:JointInference: Simple model likelihood: -96.71112343296987, Complex model likelihood: -95.88364808081883, Total degrees of freedom: 1, Parameters at boundary: 0.
# 0.19828645095495898

# %% [markdown]
# The test is not significant, indicating that the simpler model of sharing the parameters explains the data sufficiently well. Indeed, we do not observe a lot of differences between the inferred parameters of joint and the marginal inferences.

# %% [markdown]
# ## Covariates
# {class}`~fastdfe.joint_inference.JointInference` also supports the inclusion of covariates associates with the different SFS types. This provides more powerful model testing and reduces the number of parameters that need to be estimated for the joint inference. For a more interesting example we stratify the SFS of `B. pendula` by the sites' reference base as is described in more detail in the {mod}`~fastdfe.parser` module.

# %%
# instantiate parser
p = fd.Parser(
    n=10,
    vcf="https://github.com/Sendrowski/fastDFE/"
        "blob/dev/resources/genome/betula/"
        "all.polarized.deg.subset.200000.vcf.gz?raw=true",
    stratifications=[fd.DegeneracyStratification(), fd.AncestralBaseStratification()]
)

# parse SFS
spectra: fd.Spectra = p.parse()

# visualize spectra
spectra.plot();
# Out:
# INFO:Parser: Using stratification: [neutral, selected].[A, C, G, T].
# INFO:Parser: Loading VCF file
# INFO:FileHandler: Using cached file at /var/folders/w6/18ktl5312413jw46btlxrh59fzxvt4/T/011b01ee5cec.all.polarized.deg.subset.200000.vcf.gz
# INFO:FileHandler: Using cached file at /var/folders/w6/18ktl5312413jw46btlxrh59fzxvt4/T/011b01ee5cec.all.polarized.deg.subset.200000.vcf.gz
# Parser>Counting sites: 200000it [00:02, 96909.74it/s]
# Parser>Processing sites: 100%|██████████| 200000/200000 [02:21<00:00, 1411.16it/s]
# INFO:PolyAllelicFiltration: Filtered out 154 sites.
# INFO:DegeneracyStratification: Number of sites with valid type: 64083
# INFO:AncestralBaseStratification: Number of sites with valid type: 64083
# INFO:Parser: Skipped 983 sites without ancestral allele information.
# INFO:Parser: Included 64083 out of 200000 sites in total from the VCF file.

# %% [markdown]
# We now create the inference object from the spectra. In this contrived example we make up some covariates that covary with ``S_d``, the mean strength of negative selection. Covariates introduce a linear relationship by default but this can be modified by specifying a custom callback function (see {class}`~fastdfe.optimization.Covariate`).

# %%
# create inference object
inf = fd.JointInference(
    sfs_neut=spectra[['neutral.*']].merge_groups(1),
    sfs_sel=spectra[['selected.*']].merge_groups(1),
    covariates=[fd.Covariate(param='S_d', values=dict(A=1, C=2, T=3, G=4))],
    n_runs=50  # increase number of initial runs for stability
)

# run inference
inf.run();
# Out:
# INFO:JointInference: Parameters ['S_d'] have covariates and thus need to be shared. Adding them to shared parameters.
# INFO:JointInference: Using shared parameters [SharedParams(params=['S_d'], types=['A', 'C', 'G', 'T'])].
# INFO:JointInference: Including covariates: {'c0': {'param': 'S_d', 'values': {'A': 1, 'C': 2, 'T': 3, 'G': 4}}}.
# INFO:JointInference: Running marginal inference for type 'all'.
# INFO:Discretization: Precomputing semidominant DFE-SFS transformation using midpoint integration.
# Discretization>Precomputing: 100%|██████████| 9/9 [00:00<00:00, 10.62it/s]
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 51.55it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 15 iterations and 138 function evaluations, obtaining a log-likelihood of -26.61
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1069, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 7768, all.b: 0.001039, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 0.0224}.
# INFO:JointInference: Running marginal inferences for types ['A', 'C', 'G', 'T'].
# INFO:JointInference: Running marginal inference for type 'A'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 54.91it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# WARNING:BaseInference: The L1 residual comparing the modelled and observed SFS is rather large: `norm(sfs_modelled - sfs_observed, 1) / sfs_observed` = 0.200. This may indicate that the model does not fit the data well.
# INFO:BaseInference: Successfully finished optimization after 13 iterations and 51 function evaluations, obtaining a log-likelihood of -22.72
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.0857, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 0, all.b: 1.52e-08, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 1.426e-11}.
# INFO:JointInference: Running marginal inference for type 'C'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:01<00:00, 46.90it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 25 iterations and 93 function evaluations, obtaining a log-likelihood of -19.47
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1219, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 3230, all.b: 0.0004152, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 0.0001155}.
# INFO:JointInference: Running marginal inference for type 'G'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 55.51it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 15 iterations and 54 function evaluations, obtaining a log-likelihood of -18.88
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1221, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.696e+04, all.b: 0.02449, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 0.432}.
# INFO:JointInference: Running marginal inference for type 'T'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 53.23it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 17 iterations and 66 function evaluations, obtaining a log-likelihood of -18.44
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1079, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 7923, all.b: 0.001079, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 0.003898}.
# INFO:JointInference: Running joint inference for types ['A', 'C', 'G', 'T'].
# INFO:Optimization: Optimizing 6 parameters: [A:C:G:T.c0, A:C:G:T.S_d, T.b, A.b, G.b, C.b].
# JointInference>Performing joint inference: 100%|██████████| 50/50 [00:08<00:00,  5.85it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {A:C:G:T.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# WARNING:JointInference: Numerical optimization did not terminate normally, so the result might be unreliable. Consider adjusting the optimization parameters (increasing `gtol` or `n_runs`) or decreasing the number of optimized parameters.
# INFO:JointInference: Inferred parameters: {A.b: 0.0857, A.p_b: 0, A.S_b: 1, A.eps: 0, A.h: 0.5, A.S_d: -1e+05, A.c0: 0, C.b: 0.1219, C.p_b: 0, C.S_b: 1, C.eps: 0, C.h: 0.5, C.S_d: -1e+05, C.c0: 0, G.b: 0.1221, G.p_b: 0, G.S_b: 1, G.eps: 0, G.h: 0.5, G.S_d: -1e+05, G.c0: 0, T.b: 0.1079, T.p_b: 0, T.S_b: 1, T.eps: 0, T.h: 0.5, T.S_d: -1e+05, T.c0: 0}.
# INFO:JointInference: Standard deviations across runs: {A.b: 3.486, A.p_b: 0, A.S_b: 0, A.eps: 0, A.h: 0, C.b: 1.648, C.p_b: 0, C.S_b: 0, C.eps: 0, C.h: 0, G.b: 0.4854, G.p_b: 0, G.S_b: 0, G.eps: 0, G.h: 0, T.b: 2.069, T.p_b: 0, T.S_b: 0, T.eps: 0, T.h: 0, A:C:G:T.S_d: 5.008e+04, A:C:G:T.c0: 5788, likelihood: 403}.
# WARNING:BaseInference: The L1 residual comparing the modelled and observed SFS is rather large: `norm(sfs_modelled - sfs_observed, 1) / sfs_observed` = 0.200. This may indicate that the model does not fit the data well.
# INFO:JointInference: Bootstrapping type 'all'.
# BaseInference>Bootstrapping 'all' (2 runs each): 100%|██████████| 100/100 [00:03<00:00, 32.13it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.768e+04, all.b: 0.02607, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 6.379, i_best_run: 0.4924, likelihoods_std: 0.006155}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.0006828.
# INFO:JointInference: Bootstrapping type 'A'.
# BaseInference>Bootstrapping 'A' (2 runs each): 100%|██████████| 100/100 [00:02<00:00, 34.06it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.077e+04, all.b: 0.04393, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 177, i_best_run: 0.5, likelihoods_std: 0.2583}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.02777.
# INFO:JointInference: Bootstrapping type 'C'.
# BaseInference>Bootstrapping 'C' (2 runs each): 100%|██████████| 100/100 [00:03<00:00, 31.74it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.828e+04, all.b: 0.08441, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 153.4, i_best_run: 0.5024, likelihoods_std: 0.008056}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.001024.
# INFO:JointInference: Bootstrapping type 'G'.
# BaseInference>Bootstrapping 'G' (2 runs each): 100%|██████████| 100/100 [00:03<00:00, 31.15it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.702e+04, all.b: 0.0658, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 222.6, i_best_run: 0.5009, likelihoods_std: 0.01018}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.001112.
# INFO:JointInference: Bootstrapping type 'T'.
# BaseInference>Bootstrapping 'T' (2 runs each): 100%|██████████| 100/100 [00:03<00:00, 29.42it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.708e+04, all.b: 0.08804, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 82.44, i_best_run: 0.4943, likelihoods_std: 0.1064}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.01141.
# JointInference>Bootstrapping joint inference (2 runs each): 100%|██████████| 100/100 [00:26<00:00,  3.80it/s]
# INFO:JointInference: Standard deviations across bootstraps: {A.b: 0.02127, A.p_b: 0, A.S_b: 0, A.eps: 0, A.h: 0, A.S_d: 4.049e+04, A.c0: 1036, C.b: 0.02917, C.p_b: 0, C.S_b: 0, C.eps: 0, C.h: 0, C.S_d: 4.026e+04, C.c0: 1036, G.b: 0.03463, G.p_b: 0, G.S_b: 0, G.eps: 0, G.h: 0, G.S_d: 3.988e+04, G.c0: 1036, T.b: 0.02853, T.p_b: 0, T.S_b: 0, T.eps: 0, T.h: 0, T.S_d: 4.006e+04, T.c0: 1036, likelihood: 539.3, i_best_run: 0.4408, likelihoods_std: 206.8}.
# INFO:JointInference: Average standard deviation of likelihoods across runs within bootstrap samples: 156.7.

# %% [markdown]
# Let's visualize the inferred parameters

# %%
inf.plot_inferred_parameters();

# %% [markdown]
# We see that ``S_d`` does not vary markedly across the jointly-inferred types and this is because it does not vary linearly along the arbitrary covariates we specified. Indeed, looking at the mean over all bootstraps for our covariate we see that it is close to 0. Note that covariates are named ``c0``, ``c1``, etc. by default.

# %%
inf.bootstraps['A.c0'].mean()
# Out:
# -147.1703829844462

# %% [markdown]
# ### Model comparison
# We can perform a likelihood ratio test to see whether including the covariates produces a significantly better fit than simply sharing the parameter in question among the types (cf. {func}`~fastdfe.joint_inference.JointInference.perform_lrt_covariates`).

# %%
inf.perform_lrt_covariates()
# Out:
# INFO:JointInference: Using shared parameters [SharedParams(params=['S_d'], types=['A', 'C', 'G', 'T'])].
# INFO:JointInference: Including covariates: {}.
# INFO:JointInference: Running joint inference without covariates.
# INFO:JointInference: Running marginal inference for type 'all'.
# INFO:Discretization: Precomputing DFE-SFS transformation across dominance coefficients (grid size: 21).
# Discretization>Precomputing: 100%|██████████| 37989/37989 [10:36<00:00, 59.67it/s]
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:01<00:00, 30.13it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 15 iterations and 63 function evaluations, obtaining a log-likelihood of -26.61
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1069, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 3826, all.b: 0.0004633, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 0.008197}.
# INFO:JointInference: Running marginal inferences for types ['A', 'C', 'G', 'T'].
# INFO:JointInference: Running marginal inference for type 'A'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:01<00:00, 31.99it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# WARNING:BaseInference: The L1 residual comparing the modelled and observed SFS is rather large: `norm(sfs_modelled - sfs_observed, 1) / sfs_observed` = 0.200. This may indicate that the model does not fit the data well.
# INFO:BaseInference: Successfully finished optimization after 7 iterations and 48 function evaluations, obtaining a log-likelihood of -22.72
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.0857, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.252e+04, all.b: 0.001818, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 0.02547}.
# INFO:JointInference: Running marginal inference for type 'C'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:01<00:00, 27.74it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 9 iterations and 66 function evaluations, obtaining a log-likelihood of -19.47
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1219, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 2851, all.b: 0.0003684, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 0.0001038}.
# INFO:JointInference: Running marginal inference for type 'G'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:01<00:00, 31.47it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 18 iterations and 72 function evaluations, obtaining a log-likelihood of -18.88
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1221, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 9954, all.b: 0.001832, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 0.00948}.
# INFO:JointInference: Running marginal inference for type 'T'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:01<00:00, 31.36it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 14 iterations and 57 function evaluations, obtaining a log-likelihood of -18.44
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1079, all.p_b: 0, all.S_b: 1, all.eps: 0, all.h: 0.5}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 6450, all.b: 0.0008165, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 0.002735}.
# INFO:JointInference: Running joint inference for types ['A', 'C', 'G', 'T'].
# INFO:Optimization: Optimizing 5 parameters: [A:C:G:T.S_d, T.b, G.b, A.b, C.b].
# JointInference>Performing joint inference: 100%|██████████| 50/50 [00:16<00:00,  2.94it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {A:C:G:T.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# WARNING:JointInference: Numerical optimization did not terminate normally, so the result might be unreliable. Consider adjusting the optimization parameters (increasing `gtol` or `n_runs`) or decreasing the number of optimized parameters.
# INFO:JointInference: Inferred parameters: {A.b: 0.0857, A.p_b: 0, A.S_b: 1, A.eps: 0, A.h: 0.5, A.S_d: -1e+05, C.b: 0.1219, C.p_b: 0, C.S_b: 1, C.eps: 0, C.h: 0.5, C.S_d: -1e+05, G.b: 0.1221, G.p_b: 0, G.S_b: 1, G.eps: 0, G.h: 0.5, G.S_d: -1e+05, T.b: 0.1079, T.p_b: 0, T.S_b: 1, T.eps: 0, T.h: 0.5, T.S_d: -1e+05}.
# INFO:JointInference: Standard deviations across runs: {A.b: 0.0007362, A.p_b: 0, A.S_b: 0, A.eps: 0, A.h: 0, C.b: 0.001145, C.p_b: 0, C.S_b: 0, C.eps: 0, C.h: 0, G.b: 0.001089, G.p_b: 0, G.S_b: 0, G.eps: 0, G.h: 0, T.b: 0.0009359, T.p_b: 0, T.S_b: 0, T.eps: 0, T.h: 0, A:C:G:T.S_d: 7502, likelihood: 0.02113}.
# WARNING:BaseInference: The L1 residual comparing the modelled and observed SFS is rather large: `norm(sfs_modelled - sfs_observed, 1) / sfs_observed` = 0.200. This may indicate that the model does not fit the data well.
# INFO:JointInference: Bootstrapping type 'all'.
# BaseInference>Bootstrapping 'all' (2 runs each): 100%|██████████| 100/100 [00:05<00:00, 19.06it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.768e+04, all.b: 0.02607, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 6.379, i_best_run: 0.5016, likelihoods_std: 0.006173}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.0007133.
# INFO:JointInference: Bootstrapping type 'A'.
# BaseInference>Bootstrapping 'A' (2 runs each): 100%|██████████| 100/100 [00:05<00:00, 19.98it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.077e+04, all.b: 0.04393, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 177, i_best_run: 0.4976, likelihoods_std: 0.2583}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.02792.
# INFO:JointInference: Bootstrapping type 'C'.
# BaseInference>Bootstrapping 'C' (2 runs each): 100%|██████████| 100/100 [00:05<00:00, 17.97it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.828e+04, all.b: 0.08442, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 153.4, i_best_run: 0.5009, likelihoods_std: 0.007718}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.0007786.
# INFO:JointInference: Bootstrapping type 'G'.
# BaseInference>Bootstrapping 'G' (2 runs each): 100%|██████████| 100/100 [00:05<00:00, 18.64it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.703e+04, all.b: 0.06581, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 222.6, i_best_run: 0.5, likelihoods_std: 0.01524}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.002162.
# INFO:JointInference: Bootstrapping type 'T'.
# BaseInference>Bootstrapping 'T' (2 runs each): 100%|██████████| 100/100 [00:05<00:00, 17.95it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.708e+04, all.b: 0.08804, all.p_b: 0, all.S_b: 0, all.eps: 0, all.h: 0, likelihood: 82.44, i_best_run: 0.4943, likelihoods_std: 0.1067}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.0129.
# JointInference>Bootstrapping joint inference (2 runs each): 100%|██████████| 100/100 [00:49<00:00,  2.03it/s]
# INFO:JointInference: Standard deviations across bootstraps: {A.b: 0.02113, A.p_b: 0, A.S_b: 0, A.eps: 0, A.h: 0, A.S_d: 3.986e+04, C.b: 0.02906, C.p_b: 0, C.S_b: 0, C.eps: 0, C.h: 0, C.S_d: 3.986e+04, G.b: 0.03457, G.p_b: 0, G.S_b: 0, G.eps: 0, G.h: 0, G.S_d: 3.986e+04, T.b: 0.02841, T.p_b: 0, T.S_b: 0, T.eps: 0, T.h: 0, T.S_d: 3.986e+04, likelihood: 539.3, i_best_run: 0.5021, likelihoods_std: 15.45}.
# INFO:JointInference: Average standard deviation of likelihoods across runs within bootstrap samples: 1.551.
# INFO:JointInference: Simple model likelihood: -502.62728632121707, Complex model likelihood: -502.6211808249244, Total degrees of freedom: 1, Parameters at boundary: 0.
# 0.912010185245715

# %% [markdown]
# As expected, the specified covariates do not improve the fit significantly.
