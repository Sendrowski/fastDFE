# %% [markdown]
# # DFE inference
# ## Base inference
# A short overview of basic DFE inference and bootstrapping is available in the {doc}`quickstart guide <../Python/quickstart>`. DFE inference requires one `neutral` and one `selected` SFS. In this example we use the bundled `Betula pendula` (silver birch) data. By default, bootstrapping is performed automatically, and the inference estimates only the deleterious component of the DFE using {class}`~fastdfe.parametrization.GammaExpParametrization`.

# %%
import matplotlib.pyplot as plt
import numpy as np

plt.rcParams['figure.figsize'] = [4.8, 3.3]
plt.rcParams['xtick.labelsize'] = 9
plt.rcParams['ytick.labelsize'] = 9

np.set_printoptions(legacy='1.21')

# %%
import fastdfe as fd

sfs_neut=fd.Spectrum([177130, 997, 441, 228, 156, 117, 114, 83, 105, 109, 0])
sfs_sel=fd.Spectrum([797939, 1329, 499, 265, 162, 104, 117, 90, 94, 119, 0])

inf = fd.BaseInference(
    sfs_neut=sfs_neut,
    sfs_sel=sfs_sel
)

# run inference
inf.run()

inf.plot_discretized();
# Out:
# INFO:Discretization: Precomputing linear DFE-SFS transformation using midpoint integration.
# Discretization>Precomputing: 100%|██████████| 9/9 [00:00<00:00, 17.09it/s]
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 64.34it/s]
# INFO:BaseInference: Successfully finished optimization after 18 iterations and 84 function evaluations, obtaining a log-likelihood of -35.44
# INFO:BaseInference: Inferred parameters: {all.S_d: -3.389e+04, all.b: 0.1305, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.061e+04, all.b: 0.04187, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 7.282}.
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 66.29it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.862e+04, all.b: 0.02186, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 5.922, i_best_run: 0.5016, likelihoods_std: 0.04005}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.005547.

# %% [markdown]
# It is always good practice to check the variability of estimates across optimization runs to ensure stability. Here, both the standard deviations across initial runs and across runs within each bootstrap sample are low, indicating stable estimates. Individual runs and bootstrap results can be inspected in the corresponding dataframes (cf. {attr}`~fastdfe.base_inference.BaseInference.runs` and {attr}`~fastdfe.base_inference.BaseInference.bootstraps`).

# %%
inf.runs.select_dtypes('number')
# Out:
#         all.S_d     all.b  all.p_b  all.S_b  all.eps  likelihood
# 0 -33894.479346  0.130544      0.0      1.0      0.0  -35.437968
# 1 -33892.292314  0.130545      0.0      1.0      0.0  -35.437968
# 2 -33893.761506  0.130545      0.0      1.0      0.0  -35.437968
# 3 -33894.164414  0.130544      0.0      1.0      0.0  -35.437968
# 4   -355.991484  0.262963      0.0      1.0      0.0  -58.464738
# 5 -33887.918946  0.130547      0.0      1.0      0.0  -35.437969
# 6 -33891.403575  0.130546      0.0      1.0      0.0  -35.437968
# 7 -33894.941121  0.130544      0.0      1.0      0.0  -35.437968
# 8 -33892.360960  0.130545      0.0      1.0      0.0  -35.437968
# 9 -33895.503109  0.130544      0.0      1.0      0.0  -35.437968

# %%
inf.bootstraps.select_dtypes('number')
# Out:
#               S_d         b  p_b  S_b  eps  likelihood  i_best_run  \
# 0  -100000.000000  0.115271  0.0  1.0  0.0  -48.666719           0
# 1   -23098.678289  0.132768  0.0  1.0  0.0  -39.454392           0
# 2   -30895.774700  0.126525  0.0  1.0  0.0  -44.116520           1
# 3  -100000.000000  0.117041  0.0  1.0  0.0  -40.332661           0
# 4   -27265.618597  0.134771  0.0  1.0  0.0  -38.642477           0
# ..            ...       ...  ...  ...  ...         ...         ...
# 95  -59605.496209  0.121741  0.0  1.0  0.0  -38.589821           1
# 96   -3523.577668  0.172044  0.0  1.0  0.0  -33.468514           1
# 97 -100000.000000  0.114860  0.0  1.0  0.0  -44.168668           1
# 98   -5645.620874  0.160873  0.0  1.0  0.0  -34.451027           1
# 99  -12974.410539  0.146724  0.0  1.0  0.0  -36.749411           1
#
#     likelihoods_std  alpha
# 0      2.112756e-09    0.0
# 1      1.061835e-10    0.0
# 2      8.100187e-11    0.0
# 3      1.477929e-12    0.0
# 4      1.989520e-12    0.0
# ..              ...    ...
# 95     3.291802e-10    0.0
# 96     1.801936e-10    0.0
# 97     3.817790e-01    0.0
# 98     1.286082e-10    0.0
# 99     2.667946e-10    0.0
#
# [100 rows x 9 columns]

# %% [markdown]
# ### Fixing parameters
# Parameters can be held fixed during maximum-likelihood optimization. In fact, this was already done internally when restricting inference to the deleterious part of the DFE. To estimate the full DFE instead, pass an empty dictionary to fixed_params (cf. {attr}`~fastdfe.base_inference.BaseInference.fixed_params`). Note that this includes fitting the ancestral-allele misidentification rate ``eps`` as well as the beneficial DFE parameters ``S_b`` and ``p_b`` of {class}`~fastdfe.parametrization.GammaExpParametrization`.

# %%
# create inference object
inf = fd.BaseInference(
    sfs_neut=sfs_neut,
    sfs_sel=sfs_sel,
    fixed_params={},
    do_bootstrap=True
)

# run inference
inf.run()

inf.plot_discretized();
# Out:
# INFO:Discretization: Precomputing linear DFE-SFS transformation using midpoint integration.
# Discretization>Precomputing: 100%|██████████| 9/9 [00:00<00:00, 45.30it/s]
# INFO:Optimization: Optimizing 5 parameters: [all.eps, all.p_b, all.S_d, all.b, all.S_b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 10.87it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.p_b: (0, 0, 0.5)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 35 iterations and 252 function evaluations, obtaining a log-likelihood of -34.63
# INFO:BaseInference: Inferred parameters: {all.S_d: -1.004e+04, all.b: 0.1508, all.p_b: 0, all.S_b: 0.0004289, all.eps: 0.006854}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1929, all.b: 0.002536, all.p_b: 0.003763, all.S_b: 0.054, all.eps: 0.0004506, likelihood: 0.02432}.
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:10<00:00,  9.88it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.371e+04, all.b: 2.142, all.p_b: 0.08958, all.S_b: 0.2683, all.eps: 0.006756, likelihood: 5.64, i_best_run: 0.496, likelihoods_std: 0.08957}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.02142.

# %% [markdown]
# The inferred full DFE shows substantial uncertainty, which is expected with a small sample and few SNPs. This is most pronounced for the [-1, 0] and [0, 1] bins, where many mutations are effectively neutral and provide little signal. Adjusting the discretization intervals can help reveal the structure more clearly (cf. {func}`~fastdfe.base_inference.BaseInference.plot_discretized`).

# %%
inf.plot_discretized(intervals=[-np.inf, -100, -10, -1, 1, np.inf]);

# %% [markdown]
# ### Nested model comparison
# We can automatically check for the significance of include ancestral-allele misidentification and beneficial fitness affects using likelihood ratio test (LRTs). This is done with {func}`~fastdfe.base_inference.BaseInference.plot_nested_models`. The LRTs are performed by comparing the likelihood of the inferred DFE to the likelihood of a nested model where some parameters are held fixed.

# %%
# set logging level to warning to avoid cluttering
fd.logger.setLevel('WARNING')

inf.plot_nested_models()

fd.logger.setLevel('INFO')
# Out:
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:01<00:00,  8.07it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {all.S_b: (0.0001, 100, 100)} and lower bound for {all.p_b: (0, 0.0043680024, 0.5)} [(lower, value, upper)], but this might be nothing to worry about.
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:07<00:00, 12.78it/s]
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:01<00:00,  7.00it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.p_b: (0, 0, 0.5)} [(lower, value, upper)], but this might be nothing to worry about.
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:10<00:00,  9.68it/s]
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:01<00:00,  9.86it/s]
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:06<00:00, 15.32it/s]
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:01<00:00,  9.45it/s]
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:06<00:00, 15.42it/s]

# %% [markdown]
# Including ancestral allele mis-identification appears to improve the fit significantly when modelling the deleterious DFE.

# %% [markdown]
# ### Serialization
# Inference objects can be serialized to JSON files for later use (cf. {func}`~fastdfe.base_inference.BaseInference.to_file`).

# %%
# save the inference object to a file
# we can unserialized the inference by using BaseInference.from_file
inf.to_file("out/serialized.json")

# we can also save a short summary to fa ile
inf.get_summary().to_file("out/summary.json")

# %% [markdown]
# ## Folded inference
# To infer the DFE from a folded SFS, simply pass folded spectra to {class}`~fastdfe.base_inference.BaseInference`. Folded inference is performed whenever the spectra are folded, i.e., when all entries where the derived allele is the major allele are zero. Folded spectra contain little information on beneficial mutations so we only infer the deleterious part of the DFE here.

# %%
import matplotlib.pyplot as plt
import numpy as np

# create inference object
inf = fd.BaseInference(
    sfs_neut=sfs_neut.fold(),
    sfs_sel=sfs_sel.fold()
)

# run inference
inf.run()

# plot the inferred DFE and the SFS comparison
ax1, ax2 = plt.subplots(ncols=2, figsize=(7, 3.2))[1]

inf.plot_discretized(ax=ax1, show=False, intervals=np.array([-np.inf, -100, -10, -1, 0]))
inf.plot_sfs_comparison(ax=ax2, show=False)

plt.tight_layout()
plt.show()
# Out:
# INFO:Discretization: Precomputing linear DFE-SFS transformation using midpoint integration.
# Discretization>Precomputing: 100%|██████████| 9/9 [00:00<00:00, 44.94it/s]
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 58.41it/s]
# INFO:BaseInference: Successfully finished optimization after 18 iterations and 78 function evaluations, obtaining a log-likelihood of -21.58
# INFO:BaseInference: Inferred parameters: {all.S_d: -1.558e+04, all.b: 0.1464, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.469, all.b: 1.718e-06, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 3.979e-09}.
# BaseInference>Bootstrapping (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 53.34it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.881e+04, all.b: 0.02691, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 4.188, i_best_run: 0.5024, likelihoods_std: 0.001316}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.0001316.

# %% [markdown]
# ## Joint inference
# fastDFE supports joint inference of several SFS types, where any parameters can be shared between types. In this example, we create a {class}`~fastdfe.joint_inference.JointInference` object with two types, where we share ``eps``, the rate of ancestral misidentification and ``S_d``, the mean selection coefficient for deleterious mutations (cf. {class}`~fastdfe.parametrization.GammaExpParametrization`). For more complex stratifications, see the {class}`~fastdfe.parser.Parser`) module.

# %%
# neutral SFS for two types
sfs_neut = fd.Spectra(dict(
    pendula=[177130, 997, 441, 228, 156, 117, 114, 83, 105, 109, 0],
    pubescens=[172528, 3612, 1359, 790, 584, 427, 325, 234, 166, 76, 31]
))

# selected SFS for two types
sfs_sel = fd.Spectra(dict(
    pendula=[797939, 1329, 499, 265, 162, 104, 117, 90, 94, 119, 0],
    pubescens=[791106, 5326, 1741, 1005, 756, 546, 416, 294, 177, 104, 41]
))

# create inference object
inf = fd.JointInference(
    sfs_neut=sfs_neut,
    sfs_sel=sfs_sel,
    shared_params=[fd.SharedParams(types=["pendula", "pubescens"], params=["S_d"])],
    do_bootstrap=True
)

# run inference
inf.run();
# Out:
# INFO:JointInference: Using shared parameters [SharedParams(params=['S_d'], types=['pendula', 'pubescens'])].
# INFO:JointInference: Including covariates: {}.
# INFO:JointInference: Running marginal inference for type 'all'.
# INFO:Discretization: Precomputing linear DFE-SFS transformation using midpoint integration.
# Discretization>Precomputing: 100%|██████████| 9/9 [00:00<00:00, 44.68it/s]
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 69.85it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 20 iterations and 72 function evaluations, obtaining a log-likelihood of -45.09
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1066, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 5363, all.b: 0.0005904, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 0.03456}.
# INFO:JointInference: Running marginal inferences for types ['pendula', 'pubescens'].
# INFO:JointInference: Running marginal inference for type 'pendula'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 65.09it/s]
# INFO:BaseInference: Successfully finished optimization after 18 iterations and 84 function evaluations, obtaining a log-likelihood of -35.44
# INFO:BaseInference: Inferred parameters: {all.S_d: -3.389e+04, all.b: 0.1305, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.061e+04, all.b: 0.04187, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 7.282}.
# INFO:JointInference: Running marginal inference for type 'pubescens'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 10/10 [00:00<00:00, 79.93it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 10 iterations and 69 function evaluations, obtaining a log-likelihood of -43.81
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1035, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1553, all.b: 0.0001579, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 0.01935}.
# INFO:JointInference: Running joint inference for types ['pendula', 'pubescens'].
# INFO:Optimization: Optimizing 3 parameters: [pubescens.b, pendula:pubescens.S_d, pendula.b].
# JointInference>Performing joint inference: 100%|██████████| 10/10 [00:00<00:00, 24.33it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {pendula:pubescens.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:JointInference: Successfully finished optimization after 18 iterations and 172 function evaluations, obtaining a log-likelihood of -79.46
# INFO:JointInference: Inferred parameters: {pendula.b: 0.1168, pendula.p_b: 0, pendula.S_b: 1, pendula.eps: 0, pendula.S_d: -1e+05, pubescens.b: 0.1035, pubescens.p_b: 0, pubescens.S_b: 1, pubescens.eps: 0, pubescens.S_d: -1e+05}.
# INFO:JointInference: Standard deviations across runs: {pendula.b: 8.507e-09, pendula.p_b: 0, pendula.S_b: 0, pendula.eps: 0, pubescens.b: 1.709e-08, pubescens.p_b: 0, pubescens.S_b: 0, pubescens.eps: 0, pendula:pubescens.S_d: 0, likelihood: 5.483e-10}.
# INFO:JointInference: Bootstrapping type 'all'.
# BaseInference>Bootstrapping 'all' (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 74.26it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 2.664e+04, all.b: 0.007316, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 7.53, i_best_run: 0.5009, likelihoods_std: 0.001728}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.0003249.
# INFO:JointInference: Bootstrapping type 'pendula'.
# BaseInference>Bootstrapping 'pendula' (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 55.18it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.862e+04, all.b: 0.02186, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 5.922, i_best_run: 0.5016, likelihoods_std: 0.04005}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.005547.
# INFO:JointInference: Bootstrapping type 'pubescens'.
# BaseInference>Bootstrapping 'pubescens' (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 71.96it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 2.121e+04, all.b: 0.005512, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 7.557, i_best_run: 0.5, likelihoods_std: 3.78e-09}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 8.682e-10.
# JointInference>Bootstrapping joint inference (2 runs each): 100%|██████████| 100/100 [00:18<00:00,  5.51it/s]
# INFO:JointInference: Standard deviations across bootstraps: {pendula.b: 0.006864, pendula.p_b: 0, pendula.S_b: 0, pendula.eps: 0, pendula.S_d: 2.49e+04, pubescens.b: 0.005859, pubescens.p_b: 0, pubescens.S_b: 0, pubescens.eps: 0, pubescens.S_d: 2.49e+04, likelihood: 9.248, i_best_run: 0.4852, likelihoods_std: 0.01318}.
# INFO:JointInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.002692.

# %% [markdown]
# {class}`~fastdfe.joint_inference.JointInference` both runs the joint inference and marginal inference where each type is inferred separately. To see this better we can plot the inferred parameters for the different inference types.

# %%
inf.plot_inferred_parameters();

# %% [markdown]
# ``marginal.pendula`` and ``marginal.pubescens`` are the marginal inferences for the respective type. ``marginal.all`` is the marginal inference obtaining by adding up the spectra of all types. ``joint.pendula`` and ``join.pubescens`` are the joint inferences for the respective type. We can see that ``eps`` and ``S_d`` are indeed shared between the two. The parameter ``alpha`` in the plot denotes the proportion of beneficial non-synonymous substitutions. Each marginal inference is a {class}`~fastdfe.base_inference.BaseInference` object itself and can be accessed via ``inf.marginal_inferences[type]``.
#
# We can now also investigate to what extent the inferred DFEs differ:

# %%
inf.plot_discretized();

# %% [markdown]
# ### Model comparison
# We can obtain information about the goodness of fit achieved by sharing the parameter by performing a likelihood ratio test (cf. {func}`~fastdfe.joint_inference.JointInference.perform_lrt_shared`). This compares the likelihood of the joint inference with the product of the marginal likelihoods.

# %%
inf.perform_lrt_shared()
# Out:
# INFO:JointInference: Simple model likelihood: -96.71112343332356, Complex model likelihood: -95.88364808101053, Total degrees of freedom: 1, Parameters at boundary: 0.
# 0.19828645091103864

# %% [markdown]
# The test is not significant, indicating that the simpler model of sharing the parameters explains the data sufficiently well. Indeed, we do not observe a lot of differences between the inferred parameters of joint and the marginal inferences.

# %% [markdown]
# ## Covariates
# {class}`~fastdfe.joint_inference.JointInference` also supports the inclusion of covariates associates with the different SFS types. This provides more powerful model testing and reduces the number of parameters that need to be estimated for the joint inference. For a more interesting example we stratify the SFS of `B. pendula` by the sites' reference base as is described in more detail in the {mod}`~fastdfe.parser` module.

# %%
# instantiate parser
p = fd.Parser(
    n=10,
    vcf="https://github.com/Sendrowski/fastDFE/"
        "blob/dev/resources/genome/betula/"
        "all.polarized.deg.subset.200000.vcf.gz?raw=true",
    stratifications=[fd.DegeneracyStratification(), fd.AncestralBaseStratification()]
)

# parse SFS
spectra: fd.Spectra = p.parse()

# visualize spectra
spectra.plot();
# Out:
# INFO:Parser: Using stratification: [neutral, selected].[A, C, G, T].
# INFO:Parser: Loading VCF file
# INFO:FileHandler: Using cached file at /var/folders/w6/18ktl5312413jw46btlxrh59fzxvt4/T/011b01ee5cec.all.polarized.deg.subset.200000.vcf.gz
# INFO:FileHandler: Using cached file at /var/folders/w6/18ktl5312413jw46btlxrh59fzxvt4/T/011b01ee5cec.all.polarized.deg.subset.200000.vcf.gz
# Parser>Counting sites: 200000it [00:02, 82213.83it/s]
# Parser>Processing sites: 100%|██████████| 200000/200000 [03:44<00:00, 892.10it/s]
# INFO:PolyAllelicFiltration: Filtered out 154 sites.
# INFO:DegeneracyStratification: Number of sites with valid type: 64083
# INFO:AncestralBaseStratification: Number of sites with valid type: 64083
# INFO:Parser: Skipped 983 sites without ancestral allele information.
# INFO:Parser: Included 64083 out of 200000 sites in total from the VCF file.

# %% [markdown]
# We now create the inference object from the spectra. In this contrived example we make up some covariates that covary with ``S_d``, the mean strength of negative selection. Covariates introduce a linear relationship by default but this can be modified by specifying a custom callback function (see {class}`~fastdfe.optimization.Covariate`).

# %%
# create inference object
inf = fd.JointInference(
    sfs_neut=spectra[['neutral.*']].merge_groups(1),
    sfs_sel=spectra[['selected.*']].merge_groups(1),
    covariates=[fd.Covariate(param='S_d', values=dict(A=1, C=2, T=3, G=4))],
    n_runs=50,  # increase number of initial runs for stability
    do_bootstrap=True
)

# run inference
inf.run();
# Out:
# INFO:JointInference: Parameters ['S_d'] have covariates and thus need to be shared. Adding them to shared parameters.
# INFO:JointInference: Using shared parameters [SharedParams(params=['S_d'], types=['A', 'C', 'G', 'T'])].
# INFO:JointInference: Including covariates: {'c0': {'param': 'S_d', 'values': {'A': 1, 'C': 2, 'T': 3, 'G': 4}}}.
# INFO:JointInference: Running marginal inference for type 'all'.
# INFO:Discretization: Precomputing linear DFE-SFS transformation using midpoint integration.
# Discretization>Precomputing: 100%|██████████| 9/9 [00:00<00:00, 42.67it/s]
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 102.63it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 19 iterations and 78 function evaluations, obtaining a log-likelihood of -26.61
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1069, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.499e+04, all.b: 0.01836, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 0.9626}.
# INFO:JointInference: Running marginal inferences for types ['A', 'C', 'G', 'T'].
# INFO:JointInference: Running marginal inference for type 'A'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 114.02it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# WARNING:BaseInference: The L1 residual comparing the modelled and observed SFS is rather large: `norm(sfs_modelled - sfs_observed, 1) / sfs_observed` = 0.200. This may indicate that the model does not fit the data well.
# INFO:BaseInference: Successfully finished optimization after 13 iterations and 63 function evaluations, obtaining a log-likelihood of -22.72
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.0857, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.047e+04, all.b: 0.00117, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 0.01532}.
# INFO:JointInference: Running marginal inference for type 'C'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 95.87it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 17 iterations and 78 function evaluations, obtaining a log-likelihood of -19.47
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1219, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 2951, all.b: 0.0003727, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 0.0001095}.
# INFO:JointInference: Running marginal inference for type 'G'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 114.57it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 9 iterations and 120 function evaluations, obtaining a log-likelihood of -18.88
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1221, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.767e+04, all.b: 0.02447, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 0.4316}.
# INFO:JointInference: Running marginal inference for type 'T'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 113.14it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 6 iterations and 39 function evaluations, obtaining a log-likelihood of -18.44
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1079, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.612e+04, all.b: 0.02338, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 0.3437}.
# INFO:JointInference: Running joint inference for types ['A', 'C', 'G', 'T'].
# INFO:Optimization: Optimizing 6 parameters: [T.b, C.b, A.b, A:C:G:T.c0, A:C:G:T.S_d, G.b].
# JointInference>Performing joint inference: 100%|██████████| 50/50 [00:05<00:00,  9.07it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {A:C:G:T.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# WARNING:JointInference: Numerical optimization did not terminate normally, so the result might be unreliable. Consider adjusting the optimization parameters (increasing `gtol` or `n_runs`) or decreasing the number of optimized parameters.
# INFO:JointInference: Inferred parameters: {A.b: 0.0857, A.p_b: 0, A.S_b: 1, A.eps: 0, A.S_d: -1e+05, A.c0: 0, C.b: 0.1219, C.p_b: 0, C.S_b: 1, C.eps: 0, C.S_d: -1e+05, C.c0: 0, G.b: 0.1221, G.p_b: 0, G.S_b: 1, G.eps: 0, G.S_d: -1e+05, G.c0: 0, T.b: 0.1079, T.p_b: 0, T.S_b: 1, T.eps: 0, T.S_d: -1e+05, T.c0: 0}.
# INFO:JointInference: Standard deviations across runs: {A.b: 3.215, A.p_b: 0, A.S_b: 0, A.eps: 0, C.b: 1.995, C.p_b: 0, C.S_b: 0, C.eps: 0, G.b: 2.182, G.p_b: 0, G.S_b: 0, G.eps: 0, T.b: 0.8999, T.p_b: 0, T.S_b: 0, T.eps: 0, A:C:G:T.S_d: 5.03e+04, A:C:G:T.c0: 4939, likelihood: 414.4}.
# WARNING:BaseInference: The L1 residual comparing the modelled and observed SFS is rather large: `norm(sfs_modelled - sfs_observed, 1) / sfs_observed` = 0.200. This may indicate that the model does not fit the data well.
# INFO:JointInference: Bootstrapping type 'all'.
# BaseInference>Bootstrapping 'all' (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 79.73it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.768e+04, all.b: 0.02607, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 6.379, i_best_run: 0.4976, likelihoods_std: 0.01167}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.001836.
# INFO:JointInference: Bootstrapping type 'A'.
# BaseInference>Bootstrapping 'A' (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 87.26it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.076e+04, all.b: 0.04393, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 177, i_best_run: 0.5024, likelihoods_std: 0.2583}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.02745.
# INFO:JointInference: Bootstrapping type 'C'.
# BaseInference>Bootstrapping 'C' (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 77.94it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.828e+04, all.b: 0.08441, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 153.4, i_best_run: 0.5021, likelihoods_std: 0.02196}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.002892.
# INFO:JointInference: Bootstrapping type 'G'.
# BaseInference>Bootstrapping 'G' (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 80.51it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.702e+04, all.b: 0.0658, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 222.6, i_best_run: 0.5024, likelihoods_std: 0.01554}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.002431.
# INFO:JointInference: Bootstrapping type 'T'.
# BaseInference>Bootstrapping 'T' (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 76.99it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.708e+04, all.b: 0.08804, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 82.44, i_best_run: 0.4924, likelihoods_std: 0.1065}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.01162.
# JointInference>Bootstrapping joint inference (2 runs each): 100%|██████████| 100/100 [00:33<00:00,  2.99it/s]
# INFO:JointInference: Standard deviations across bootstraps: {A.b: 0.02152, A.p_b: 0, A.S_b: 0, A.eps: 0, A.S_d: 4.033e+04, A.c0: 1793, C.b: 0.02898, C.p_b: 0, C.S_b: 0, C.eps: 0, C.S_d: 4.014e+04, C.c0: 1793, G.b: 0.03446, G.p_b: 0, G.S_b: 0, G.eps: 0, G.S_d: 3.979e+04, G.c0: 1793, T.b: 0.02837, T.p_b: 0, T.S_b: 0, T.eps: 0, T.S_d: 3.995e+04, T.c0: 1793, likelihood: 539.3, i_best_run: 0.3861, likelihoods_std: 215.9}.
# INFO:JointInference: Average standard deviation of likelihoods across runs within bootstrap samples: 204.6.

# %% [markdown]
# Let's visualize the inferred parameters

# %%
inf.plot_inferred_parameters();

# %% [markdown]
# We see that ``S_d`` does not vary markedly across the jointly-inferred types and this is because it does not vary linearly along the arbitrary covariates we specified. Indeed, looking at the mean over all bootstraps for our covariate we see that it is close to 0. Note that covariates are named ``c0``, ``c1``, etc. by default.

# %%
inf.bootstraps['A.c0'].mean()
# Out:
# -380.9228351330103

# %% [markdown]
# ### Model comparison
# We can perform a likelihood ratio test to see whether including the covariates produces a significantly better fit than simply sharing the parameter in question among the types (cf. {func}`~fastdfe.joint_inference.JointInference.perform_lrt_covariates`).

# %%
inf.perform_lrt_covariates()
# Out:
# INFO:JointInference: Using shared parameters [SharedParams(params=['S_d'], types=['A', 'C', 'G', 'T'])].
# INFO:JointInference: Including covariates: {}.
# INFO:JointInference: Running joint inference without covariates.
# INFO:JointInference: Running marginal inference for type 'all'.
# INFO:Discretization: Precomputing linear DFE-SFS transformation using midpoint integration.
# Discretization>Precomputing: 100%|██████████| 9/9 [00:00<00:00, 41.30it/s]
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 105.27it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 19 iterations and 78 function evaluations, obtaining a log-likelihood of -26.61
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1069, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.499e+04, all.b: 0.01836, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 0.9626}.
# INFO:JointInference: Running marginal inferences for types ['A', 'C', 'G', 'T'].
# INFO:JointInference: Running marginal inference for type 'A'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 114.52it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# WARNING:BaseInference: The L1 residual comparing the modelled and observed SFS is rather large: `norm(sfs_modelled - sfs_observed, 1) / sfs_observed` = 0.200. This may indicate that the model does not fit the data well.
# INFO:BaseInference: Successfully finished optimization after 13 iterations and 63 function evaluations, obtaining a log-likelihood of -22.72
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.0857, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.047e+04, all.b: 0.00117, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 0.01532}.
# INFO:JointInference: Running marginal inference for type 'C'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 95.55it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 17 iterations and 78 function evaluations, obtaining a log-likelihood of -19.47
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1219, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 2951, all.b: 0.0003727, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 0.0001095}.
# INFO:JointInference: Running marginal inference for type 'G'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 109.97it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 9 iterations and 120 function evaluations, obtaining a log-likelihood of -18.88
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1221, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.767e+04, all.b: 0.02447, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 0.4316}.
# INFO:JointInference: Running marginal inference for type 'T'.
# INFO:Optimization: Optimizing 2 parameters: [all.S_d, all.b].
# BaseInference>Performing inference: 100%|██████████| 50/50 [00:00<00:00, 104.80it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {all.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# INFO:BaseInference: Successfully finished optimization after 6 iterations and 39 function evaluations, obtaining a log-likelihood of -18.44
# INFO:BaseInference: Inferred parameters: {all.S_d: -1e+05, all.b: 0.1079, all.p_b: 0, all.S_b: 1, all.eps: 0}.
# INFO:BaseInference: Standard deviations across runs: {all.S_d: 1.612e+04, all.b: 0.02338, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 0.3437}.
# INFO:JointInference: Running joint inference for types ['A', 'C', 'G', 'T'].
# INFO:Optimization: Optimizing 5 parameters: [T.b, C.b, A.b, A:C:G:T.S_d, G.b].
# JointInference>Performing joint inference: 100%|██████████| 50/50 [00:04<00:00, 11.76it/s]
# WARNING:Optimization: The MLE estimate is close to the upper bound for {} and lower bound for {A:C:G:T.S_d: (-100000, -100000, -0.01)} [(lower, value, upper)], but this might be nothing to worry about.
# WARNING:JointInference: Numerical optimization did not terminate normally, so the result might be unreliable. Consider adjusting the optimization parameters (increasing `gtol` or `n_runs`) or decreasing the number of optimized parameters.
# INFO:JointInference: Inferred parameters: {A.b: 0.0857, A.p_b: 0, A.S_b: 1, A.eps: 0, A.S_d: -1e+05, C.b: 0.1219, C.p_b: 0, C.S_b: 1, C.eps: 0, C.S_d: -1e+05, G.b: 0.1221, G.p_b: 0, G.S_b: 1, G.eps: 0, G.S_d: -1e+05, T.b: 0.1079, T.p_b: 0, T.S_b: 1, T.eps: 0, T.S_d: -1e+05}.
# INFO:JointInference: Standard deviations across runs: {A.b: 0.0003839, A.p_b: 0, A.S_b: 0, A.eps: 0, C.b: 0.0002633, C.p_b: 0, C.S_b: 0, C.eps: 0, G.b: 0.0004004, G.p_b: 0, G.S_b: 0, G.eps: 0, T.b: 0.0002025, T.p_b: 0, T.S_b: 0, T.eps: 0, A:C:G:T.S_d: 2657, likelihood: 0.008216}.
# WARNING:BaseInference: The L1 residual comparing the modelled and observed SFS is rather large: `norm(sfs_modelled - sfs_observed, 1) / sfs_observed` = 0.200. This may indicate that the model does not fit the data well.
# INFO:JointInference: Bootstrapping type 'all'.
# BaseInference>Bootstrapping 'all' (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 81.83it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 3.768e+04, all.b: 0.02607, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 6.379, i_best_run: 0.4976, likelihoods_std: 0.01167}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.001836.
# INFO:JointInference: Bootstrapping type 'A'.
# BaseInference>Bootstrapping 'A' (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 84.28it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.076e+04, all.b: 0.04393, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 177, i_best_run: 0.5024, likelihoods_std: 0.2583}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.02745.
# INFO:JointInference: Bootstrapping type 'C'.
# BaseInference>Bootstrapping 'C' (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 75.37it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.828e+04, all.b: 0.08441, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 153.4, i_best_run: 0.5021, likelihoods_std: 0.02196}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.002892.
# INFO:JointInference: Bootstrapping type 'G'.
# BaseInference>Bootstrapping 'G' (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 77.76it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.702e+04, all.b: 0.0658, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 222.6, i_best_run: 0.5024, likelihoods_std: 0.01554}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.002431.
# INFO:JointInference: Bootstrapping type 'T'.
# BaseInference>Bootstrapping 'T' (2 runs each): 100%|██████████| 100/100 [00:01<00:00, 70.78it/s]
# INFO:BaseInference: Standard deviations across bootstraps: {all.S_d: 4.708e+04, all.b: 0.08804, all.p_b: 0, all.S_b: 0, all.eps: 0, likelihood: 82.44, i_best_run: 0.4924, likelihoods_std: 0.1065}.
# INFO:BaseInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.01162.
# JointInference>Bootstrapping joint inference (2 runs each): 100%|██████████| 100/100 [00:32<00:00,  3.12it/s]
# INFO:JointInference: Standard deviations across bootstraps: {A.b: 0.02111, A.p_b: 0, A.S_b: 0, A.eps: 0, A.S_d: 3.992e+04, C.b: 0.02908, C.p_b: 0, C.S_b: 0, C.eps: 0, C.S_d: 3.992e+04, G.b: 0.03456, G.p_b: 0, G.S_b: 0, G.eps: 0, G.S_d: 3.992e+04, T.b: 0.02842, T.p_b: 0, T.S_b: 0, T.eps: 0, T.S_d: 3.992e+04, likelihood: 539.3, i_best_run: 0.5025, likelihoods_std: 0.01351}.
# INFO:JointInference: Average standard deviation of likelihoods across runs within bootstrap samples: 0.003114.
# INFO:JointInference: Simple model likelihood: -502.62678123293443, Complex model likelihood: -502.6269712985984, Total degrees of freedom: 1, Parameters at boundary: 0.
# 1.0

# %% [markdown]
# As expected, the specified covariates do not improve the fit significantly.
