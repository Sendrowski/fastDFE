# %% [markdown]
# # Working with SFS
# ## Subtypes
# fastDFE offers a set of utilities for handling and manipulating site-frequency spectra (SFS) data, especially when there are multiple types. The {class}`~fastdfe.spectrum.Spectra` class is designed to hold and manipulate spectra of multiple types. It provides a number of methods and properties for creating, accessing, and manipulating the spectra data. Usually we would obtain already stratified spectra from {class}`~fastdfe.parser.Parser`, but we can also create them manually.

# %%
library(fastdfe)

# load the fastdfe package
fastdfe <- load_fastdfe()

# %%
Spectrum <- fastdfe$Spectrum
Spectra <- fastdfe$Spectra

# create spectra with two subtypes and two types
spectra <- Spectra$from_spectra(list(
    subtype1.type1=Spectrum$standard_kingman(10) * 1,
    subtype1.type2=Spectrum$standard_kingman(10) * 2,
    subtype2.type1=Spectrum$standard_kingman(10) * 3
));

# plot spectra
Spectra$plot(spectra);
# Out:
# $data
#    indices   heights          group
# 1        2 1.0000000 subtype1.type1
# 2        3 0.5000000 subtype1.type1
# 3        4 0.3333333 subtype1.type1
# 4        5 0.2500000 subtype1.type1
# 5        6 0.2000000 subtype1.type1
# 6        7 0.1666667 subtype1.type1
# 7        8 0.1428571 subtype1.type1
# 8        9 0.1250000 subtype1.type1
# 9       10 0.1111111 subtype1.type1
# 10       2 2.0000000 subtype1.type2
# 11       3 1.0000000 subtype1.type2
# 12       4 0.6666667 subtype1.type2
# 13       5 0.5000000 subtype1.type2
# 14       6 0.4000000 subtype1.type2
# 15       7 0.3333333 subtype1.type2
# 16       8 0.2857143 subtype1.type2
# 17       9 0.2500000 subtype1.type2
# 18      10 0.2222222 subtype1.type2
# 19       2 3.0000000 subtype2.type1
# 20       3 1.5000000 subtype2.type1
# 21       4 1.0000000 subtype2.type1
# 22       5 0.7500000 subtype2.type1
# 23       6 0.6000000 subtype2.type1
# 24       7 0.5000000 subtype2.type1
# 25       8 0.4285714 subtype2.type1
# 26       9 0.3750000 subtype2.type1
# 27      10 0.3333333 subtype2.type1
#
# $layers
# $layers[[1]]
# geom_bar: just = 0.5, width = 0.7, na.rm = FALSE, orientation = NA
# stat_identity: na.rm = FALSE
# position_dodge
#
#
# $scales
# <ggproto object: Class ScalesList, gg>
#     add: function
#     add_defaults: function
#     add_missing: function
#     backtransform_df: function
#     clone: function
#     find: function
#     get_scales: function
#     has_scale: function
#     input: function
#     map_df: function
#     n: function
#     non_position_scales: function
#     scales: list
#     train_df: function
#     transform_df: function
#     super:  <ggproto object: Class ScalesList, gg>
#
# $guides
# <Guides[0] ggproto object>
#
# <empty>
#
# $mapping
# $mapping$x
# <quosure>
# expr: ^indices
# env:  0x7fe139c990f0
#
# $mapping$y
# <quosure>
# expr: ^heights
# env:  0x7fe139c990f0
#
# $mapping$fill
# <quosure>
# expr: ^.data$group
# env:  0x7fe139c990f0
#
#
# $theme
# $theme$line
# $theme$line$colour
# [1] "black"
#
# $theme$line$linewidth
# [1] 0.5
#
# $theme$line$linetype
# [1] 1
#
# $theme$line$lineend
# [1] "butt"
#
# $theme$line$arrow
# [1] FALSE
#
# $theme$line$inherit.blank
# [1] TRUE
#
#
# $theme$rect
# $theme$rect$fill
# [1] "white"
#
# $theme$rect$colour
# [1] "black"
#
# $theme$rect$linewidth
# [1] 0.5
#
# $theme$rect$linetype
# [1] 1
#
# $theme$rect$inherit.blank
# [1] TRUE
#
#
# $theme$text
# $theme$text$family
# [1] ""
#
# $theme$text$face
# [1] "plain"
#
# $theme$text$colour
# [1] "black"
#
# $theme$text$size
# [1] 11
#
# $theme$text$hjust
# [1] 0.5
#
# $theme$text$vjust
# [1] 0.5
#
# $theme$text$angle
# [1] 0
#
# $theme$text$lineheight
# [1] 0.9
#
# $theme$text$margin
# [1] 0 0 0 0
#
# $theme$text$debug
# [1] FALSE
#
# $theme$text$inherit.blank
# [1] TRUE
#
#
# $theme$title
# NULL
#
# $theme$aspect.ratio
# NULL
#
# $theme$axis.title
# NULL
#
# $theme$axis.title.x
# $theme$axis.title.x$family
# NULL
#
# $theme$axis.title.x$face
# NULL
#
# $theme$axis.title.x$colour
# NULL
#
# $theme$axis.title.x$size
# NULL
#
# $theme$axis.title.x$hjust
# NULL
#
# $theme$axis.title.x$vjust
# [1] 1
#
# $theme$axis.title.x$angle
# NULL
#
# $theme$axis.title.x$lineheight
# NULL
#
# $theme$axis.title.x$margin
# [1] 2.75 0.00 0.00 0.00
#
# $theme$axis.title.x$debug
# NULL
#
# $theme$axis.title.x$inherit.blank
# [1] TRUE
#
#
# $theme$axis.title.x.top
# $theme$axis.title.x.top$family
# NULL
#
# $theme$axis.title.x.top$face
# NULL
#
# $theme$axis.title.x.top$colour
# NULL
#
# $theme$axis.title.x.top$size
# NULL
#
# $theme$axis.title.x.top$hjust
# NULL
#
# $theme$axis.title.x.top$vjust
# [1] 0
#
# $theme$axis.title.x.top$angle
# NULL
#
# $theme$axis.title.x.top$lineheight
# NULL
#
# $theme$axis.title.x.top$margin
# [1] 0.00 0.00 2.75 0.00
#
# $theme$axis.title.x.top$debug
# NULL
#
# $theme$axis.title.x.top$inherit.blank
# [1] TRUE
#
#
# $theme$axis.title.x.bottom
# NULL
#
# $theme$axis.title.y
# $theme$axis.title.y$family
# NULL
#
# $theme$axis.title.y$face
# NULL
#
# $theme$axis.title.y$colour
# NULL
#
# $theme$axis.title.y$size
# NULL
#
# $theme$axis.title.y$hjust
# NULL
#
# $theme$axis.title.y$vjust
# [1] 1
#
# $theme$axis.title.y$angle
# [1] 90
#
# $theme$axis.title.y$lineheight
# NULL
#
# $theme$axis.title.y$margin
# [1] 0.00 2.75 0.00 0.00
#
# $theme$axis.title.y$debug
# NULL
#
# $theme$axis.title.y$inherit.blank
# [1] TRUE
#
#
# $theme$axis.title.y.left
# NULL
#
# $theme$axis.title.y.right
# $theme$axis.title.y.right$family
# NULL
#
# $theme$axis.title.y.right$face
# NULL
#
# $theme$axis.title.y.right$colour
# NULL
#
# $theme$axis.title.y.right$size
# NULL
#
# $theme$axis.title.y.right$hjust
# NULL
#
# $theme$axis.title.y.right$vjust
# [1] 0
#
# $theme$axis.title.y.right$angle
# [1] -90
#
# $theme$axis.title.y.right$lineheight
# NULL
#
# $theme$axis.title.y.right$margin
# [1] 0.00 0.00 0.00 2.75
#
# $theme$axis.title.y.right$debug
# NULL
#
# $theme$axis.title.y.right$inherit.blank
# [1] TRUE
#
#
# $theme$axis.text
# $theme$axis.text$family
# NULL
#
# $theme$axis.text$face
# NULL
#
# $theme$axis.text$colour
# [1] "grey30"
#
# $theme$axis.text$size
# [1] 0.8
#
# $theme$axis.text$hjust
# NULL
#
# $theme$axis.text$vjust
# NULL
#
# $theme$axis.text$angle
# NULL
#
# $theme$axis.text$lineheight
# NULL
#
# $theme$axis.text$margin
# NULL
#
# $theme$axis.text$debug
# NULL
#
# $theme$axis.text$inherit.blank
# [1] TRUE
#
#
# $theme$axis.text.x
# $theme$axis.text.x$family
# NULL
#
# $theme$axis.text.x$face
# NULL
#
# $theme$axis.text.x$colour
# NULL
#
# $theme$axis.text.x$size
# NULL
#
# $theme$axis.text.x$hjust
# NULL
#
# $theme$axis.text.x$vjust
# [1] 1
#
# $theme$axis.text.x$angle
# NULL
#
# $theme$axis.text.x$lineheight
# NULL
#
# $theme$axis.text.x$margin
# [1] 2.2 0.0 0.0 0.0
#
# $theme$axis.text.x$debug
# NULL
#
# $theme$axis.text.x$inherit.blank
# [1] TRUE
#
#
# $theme$axis.text.x.top
# $theme$axis.text.x.top$family
# NULL
#
# $theme$axis.text.x.top$face
# NULL
#
# $theme$axis.text.x.top$colour
# NULL
#
# $theme$axis.text.x.top$size
# NULL
#
# $theme$axis.text.x.top$hjust
# NULL
#
# $theme$axis.text.x.top$vjust
# [1] 0
#
# $theme$axis.text.x.top$angle
# NULL
#
# $theme$axis.text.x.top$lineheight
# NULL
#
# $theme$axis.text.x.top$margin
# [1] 0.0 0.0 2.2 0.0
#
# $theme$axis.text.x.top$debug
# NULL
#
# $theme$axis.text.x.top$inherit.blank
# [1] TRUE
#
#
# $theme$axis.text.x.bottom
# NULL
#
# $theme$axis.text.y
# $theme$axis.text.y$family
# NULL
#
# $theme$axis.text.y$face
# NULL
#
# $theme$axis.text.y$colour
# NULL
#
# $theme$axis.text.y$size
# NULL
#
# $theme$axis.text.y$hjust
# [1] 1
#
# $theme$axis.text.y$vjust
# NULL
#
# $theme$axis.text.y$angle
# NULL
#
# $theme$axis.text.y$lineheight
# NULL
#
# $theme$axis.text.y$margin
# [1] 0.0 2.2 0.0 0.0
#
# $theme$axis.text.y$debug
# NULL
#
# $theme$axis.text.y$inherit.blank
# [1] TRUE
#
#
# $theme$axis.text.y.left
# NULL
#
# $theme$axis.text.y.right
# $theme$axis.text.y.right$family
# NULL
#
# $theme$axis.text.y.right$face
# NULL
#
# $theme$axis.text.y.right$colour
# NULL
#
# $theme$axis.text.y.right$size
# NULL
#
# $theme$axis.text.y.right$hjust
# [1] 0
#
# $theme$axis.text.y.right$vjust
# NULL
#
# $theme$axis.text.y.right$angle
# NULL
#
# $theme$axis.text.y.right$lineheight
# NULL
#
# $theme$axis.text.y.right$margin
# [1] 0.0 0.0 0.0 2.2
#
# $theme$axis.text.y.right$debug
# NULL
#
# $theme$axis.text.y.right$inherit.blank
# [1] TRUE
#
#
# $theme$axis.ticks
# $theme$axis.ticks$colour
# [1] "grey20"
#
# $theme$axis.ticks$linewidth
# NULL
#
# $theme$axis.ticks$linetype
# NULL
#
# $theme$axis.ticks$lineend
# NULL
#
# $theme$axis.ticks$arrow
# [1] FALSE
#
# $theme$axis.ticks$inherit.blank
# [1] TRUE
#
#
# $theme$axis.ticks.x
# NULL
#
# $theme$axis.ticks.x.top
# NULL
#
# $theme$axis.ticks.x.bottom
# NULL
#
# $theme$axis.ticks.y
# NULL
#
# $theme$axis.ticks.y.left
# NULL
#
# $theme$axis.ticks.y.right
# NULL
#
# $theme$axis.ticks.length
# [1] 2.75
#
# $theme$axis.ticks.length.x
# NULL
#
# $theme$axis.ticks.length.x.top
# NULL
#
# $theme$axis.ticks.length.x.bottom
# NULL
#
# $theme$axis.ticks.length.y
# NULL
#
# $theme$axis.ticks.length.y.left
# NULL
#
# $theme$axis.ticks.length.y.right
# NULL
#
# $theme$axis.line
# list()
#
# $theme$axis.line.x
# NULL
#
# $theme$axis.line.x.top
# NULL
#
# $theme$axis.line.x.bottom
# NULL
#
# $theme$axis.line.y
# NULL
#
# $theme$axis.line.y.left
# NULL
#
# $theme$axis.line.y.right
# NULL
#
# $theme$legend.background
# $theme$legend.background$fill
# NULL
#
# $theme$legend.background$colour
# [1] TRUE
#
# $theme$legend.background$linewidth
# NULL
#
# $theme$legend.background$linetype
# NULL
#
# $theme$legend.background$inherit.blank
# [1] TRUE
#
#
# $theme$legend.margin
# [1] 5.5 5.5 5.5 5.5
#
# $theme$legend.spacing
# [1] 11
#
# $theme$legend.spacing.x
# NULL
#
# $theme$legend.spacing.y
# NULL
#
# $theme$legend.key
# $theme$legend.key$fill
# [1] "white"
#
# $theme$legend.key$colour
# [1] TRUE
#
# $theme$legend.key$linewidth
# NULL
#
# $theme$legend.key$linetype
# NULL
#
# $theme$legend.key$inherit.blank
# [1] TRUE
#
#
# $theme$legend.key.size
# [1] 1.2
#
# $theme$legend.key.height
# NULL
#
# $theme$legend.key.width
# NULL
#
# $theme$legend.text
# $theme$legend.text$family
# NULL
#
# $theme$legend.text$face
# NULL
#
# $theme$legend.text$colour
# NULL
#
# $theme$legend.text$size
# [1] 0.8
#
# $theme$legend.text$hjust
# NULL
#
# $theme$legend.text$vjust
# NULL
#
# $theme$legend.text$angle
# NULL
#
# $theme$legend.text$lineheight
# NULL
#
# $theme$legend.text$margin
# NULL
#
# $theme$legend.text$debug
# NULL
#
# $theme$legend.text$inherit.blank
# [1] TRUE
#
#
# $theme$legend.title
# $theme$legend.title$family
# NULL
#
# $theme$legend.title$face
# NULL
#
# $theme$legend.title$colour
# NULL
#
# $theme$legend.title$size
# NULL
#
# $theme$legend.title$hjust
# [1] 0
#
# $theme$legend.title$vjust
# NULL
#
# $theme$legend.title$angle
# NULL
#
# $theme$legend.title$lineheight
# NULL
#
# $theme$legend.title$margin
# NULL
#
# $theme$legend.title$debug
# NULL
#
# $theme$legend.title$inherit.blank
# [1] TRUE
#
#
# $theme$legend.position
# [1] "right"
#
# $theme$legend.direction
# NULL
#
# $theme$legend.justification
# [1] "center"
#
# $theme$legend.box
# NULL
#
# $theme$legend.box.just
# NULL
#
# $theme$legend.box.margin
# [1] 0 0 0 0
#
# $theme$legend.box.background
# list()
#
# $theme$legend.box.spacing
# [1] 11
#
# $theme$panel.background
# $theme$panel.background$fill
# [1] "white"
#
# $theme$panel.background$colour
# [1] TRUE
#
# $theme$panel.background$linewidth
# NULL
#
# $theme$panel.background$linetype
# NULL
#
# $theme$panel.background$inherit.blank
# [1] TRUE
#
#
# $theme$panel.border
# $theme$panel.border$fill
# [1] TRUE
#
# $theme$panel.border$colour
# [1] "grey20"
#
# $theme$panel.border$linewidth
# NULL
#
# $theme$panel.border$linetype
# NULL
#
# $theme$panel.border$inherit.blank
# [1] TRUE
#
#
# $theme$panel.spacing
# [1] 5.5
#
# $theme$panel.spacing.x
# NULL
#
# $theme$panel.spacing.y
# NULL
#
# $theme$panel.grid
# $theme$panel.grid$colour
# [1] "grey92"
#
# $theme$panel.grid$linewidth
# NULL
#
# $theme$panel.grid$linetype
# NULL
#
# $theme$panel.grid$lineend
# NULL
#
# $theme$panel.grid$arrow
# [1] FALSE
#
# $theme$panel.grid$inherit.blank
# [1] TRUE
#
#
# $theme$panel.grid.major
# list()
#
# $theme$panel.grid.minor
# list()
#
# $theme$panel.grid.major.x
# NULL
#
# $theme$panel.grid.major.y
# NULL
#
# $theme$panel.grid.minor.x
# NULL
#
# $theme$panel.grid.minor.y
# NULL
#
# $theme$panel.ontop
# [1] FALSE
#
# $theme$plot.background
# $theme$plot.background$fill
# NULL
#
# $theme$plot.background$colour
# [1] "white"
#
# $theme$plot.background$linewidth
# NULL
#
# $theme$plot.background$linetype
# NULL
#
# $theme$plot.background$inherit.blank
# [1] TRUE
#
#
# $theme$plot.title
# $theme$plot.title$family
# NULL
#
# $theme$plot.title$face
# NULL
#
# $theme$plot.title$colour
# NULL
#
# $theme$plot.title$size
# [1] 1.2
#
# $theme$plot.title$hjust
# [1] 0
#
# $theme$plot.title$vjust
# [1] 1
#
# $theme$plot.title$angle
# NULL
#
# $theme$plot.title$lineheight
# NULL
#
# $theme$plot.title$margin
# [1] 0.0 0.0 5.5 0.0
#
# $theme$plot.title$debug
# NULL
#
# $theme$plot.title$inherit.blank
# [1] TRUE
#
#
# $theme$plot.title.position
# [1] "panel"
#
# $theme$plot.subtitle
# $theme$plot.subtitle$family
# NULL
#
# $theme$plot.subtitle$face
# NULL
#
# $theme$plot.subtitle$colour
# NULL
#
# $theme$plot.subtitle$size
# NULL
#
# $theme$plot.subtitle$hjust
# [1] 0
#
# $theme$plot.subtitle$vjust
# [1] 1
#
# $theme$plot.subtitle$angle
# NULL
#
# $theme$plot.subtitle$lineheight
# NULL
#
# $theme$plot.subtitle$margin
# [1] 0.0 0.0 5.5 0.0
#
# $theme$plot.subtitle$debug
# NULL
#
# $theme$plot.subtitle$inherit.blank
# [1] TRUE
#
#
# $theme$plot.caption
# $theme$plot.caption$family
# NULL
#
# $theme$plot.caption$face
# NULL
#
# $theme$plot.caption$colour
# NULL
#
# $theme$plot.caption$size
# [1] 0.8
#
# $theme$plot.caption$hjust
# [1] 1
#
# $theme$plot.caption$vjust
# [1] 1
#
# $theme$plot.caption$angle
# NULL
#
# $theme$plot.caption$lineheight
# NULL
#
# $theme$plot.caption$margin
# [1] 5.5 0.0 0.0 0.0
#
# $theme$plot.caption$debug
# NULL
#
# $theme$plot.caption$inherit.blank
# [1] TRUE
#
#
# $theme$plot.caption.position
# [1] "panel"
#
# $theme$plot.tag
# $theme$plot.tag$family
# NULL
#
# $theme$plot.tag$face
# NULL
#
# $theme$plot.tag$colour
# NULL
#
# $theme$plot.tag$size
# [1] 1.2
#
# $theme$plot.tag$hjust
# [1] 0.5
#
# $theme$plot.tag$vjust
# [1] 0.5
#
# $theme$plot.tag$angle
# NULL
#
# $theme$plot.tag$lineheight
# NULL
#
# $theme$plot.tag$margin
# NULL
#
# $theme$plot.tag$debug
# NULL
#
# $theme$plot.tag$inherit.blank
# [1] TRUE
#
#
# $theme$plot.tag.position
# [1] "topleft"
#
# $theme$plot.tag.location
# NULL
#
# $theme$plot.margin
# [1] 5.5 5.5 5.5 5.5
#
# $theme$strip.background
# $theme$strip.background$fill
# [1] "grey85"
#
# $theme$strip.background$colour
# [1] "grey20"
#
# $theme$strip.background$linewidth
# NULL
#
# $theme$strip.background$linetype
# NULL
#
# $theme$strip.background$inherit.blank
# [1] TRUE
#
#
# $theme$strip.background.x
# NULL
#
# $theme$strip.background.y
# NULL
#
# $theme$strip.clip
# [1] "inherit"
#
# $theme$strip.placement
# [1] "inside"
#
# $theme$strip.text
# $theme$strip.text$family
# NULL
#
# $theme$strip.text$face
# NULL
#
# $theme$strip.text$colour
# [1] "grey10"
#
# $theme$strip.text$size
# [1] 0.8
#
# $theme$strip.text$hjust
# NULL
#
# $theme$strip.text$vjust
# NULL
#
# $theme$strip.text$angle
# NULL
#
# $theme$strip.text$lineheight
# NULL
#
# $theme$strip.text$margin
# [1] 4.4 4.4 4.4 4.4
#
# $theme$strip.text$debug
# NULL
#
# $theme$strip.text$inherit.blank
# [1] TRUE
#
#
# $theme$strip.text.x
# NULL
#
# $theme$strip.text.x.bottom
# NULL
#
# $theme$strip.text.x.top
# NULL
#
# $theme$strip.text.y
# $theme$strip.text.y$family
# NULL
#
# $theme$strip.text.y$face
# NULL
#
# $theme$strip.text.y$colour
# NULL
#
# $theme$strip.text.y$size
# NULL
#
# $theme$strip.text.y$hjust
# NULL
#
# $theme$strip.text.y$vjust
# NULL
#
# $theme$strip.text.y$angle
# [1] -90
#
# $theme$strip.text.y$lineheight
# NULL
#
# $theme$strip.text.y$margin
# NULL
#
# $theme$strip.text.y$debug
# NULL
#
# $theme$strip.text.y$inherit.blank
# [1] TRUE
#
#
# $theme$strip.text.y.left
# $theme$strip.text.y.left$family
# NULL
#
# $theme$strip.text.y.left$face
# NULL
#
# $theme$strip.text.y.left$colour
# NULL
#
# $theme$strip.text.y.left$size
# NULL
#
# $theme$strip.text.y.left$hjust
# NULL
#
# $theme$strip.text.y.left$vjust
# NULL
#
# $theme$strip.text.y.left$angle
# [1] 90
#
# $theme$strip.text.y.left$lineheight
# NULL
#
# $theme$strip.text.y.left$margin
# NULL
#
# $theme$strip.text.y.left$debug
# NULL
#
# $theme$strip.text.y.left$inherit.blank
# [1] TRUE
#
#
# $theme$strip.text.y.right
# NULL
#
# $theme$strip.switch.pad.grid
# [1] 2.75
#
# $theme$strip.switch.pad.wrap
# [1] 2.75
#
#
# $coordinates
# <ggproto object: Class CoordCartesian, Coord, gg>
#     aspect: function
#     backtransform_range: function
#     clip: on
#     default: TRUE
#     distance: function
#     expand: TRUE
#     is_free: function
#     is_linear: function
#     labels: function
#     limits: list
#     modify_scales: function
#     range: function
#     render_axis_h: function
#     render_axis_v: function
#     render_bg: function
#     render_fg: function
#     setup_data: function
#     setup_layout: function
#     setup_panel_guides: function
#     setup_panel_params: function
#     setup_params: function
#     train_panel_guides: function
#     transform: function
#     super:  <ggproto object: Class CoordCartesian, Coord, gg>
#
# $facet
# <ggproto object: Class FacetNull, Facet, gg>
#     compute_layout: function
#     draw_back: function
#     draw_front: function
#     draw_labels: function
#     draw_panels: function
#     finish_data: function
#     init_scales: function
#     map_data: function
#     params: list
#     setup_data: function
#     setup_params: function
#     shrink: TRUE
#     train_scales: function
#     vars: function
#     super:  <ggproto object: Class FacetNull, Facet, gg>
#
# $plot_env
# <environment: 0x7fe139c990f0>
#
# $labels
# $labels$x
# [1] "frequency"
#
# $labels$y
# [1] ""
#
# $labels$title
# NULL
#
# $labels$fill
# [1] "group"
# plot without title

# %% [markdown]
# We access types by their index from which we obtain a {class}`~fastdfe.spectrum.Spectrum` object.

# %%
sfs: fd.Spectrum = spectra["subtype1.type1"]

sfs.plot();

# %% [markdown]
# We can also use wildcards to access multiple types at once.

# %%
spectra["subtype1.*"].plot();

# %% [markdown]
# ### Grouping
# To get rid of the subtypes, we can merge the spectra over the specified number of groups.

# %%
spectra.merge_groups(1).plot();

# %% [markdown]
# All subtypes for each type are merged into a single spectrum by adding them upp.

# %% [markdown]
# ### Serialization
# We can also save the spectra to a file and restore them again.

# %%
spectra.to_file("spectra.csv")

spectra2 = fd.Spectra.from_file("spectra.csv")

# %% [markdown]
# ### Prefixing
# Here we prefix the spectra with a string to distinguish them and then combine them into a Spectra object.

# %%
spectra.prefix('original').combine(spectra2.prefix('restored')).plot();

# %% [markdown]
# For a complete reference of the available methods and properties, see {class}`~fastdfe.spectrum.Spectra` and {class}`~fastdfe.spectrum.Spectrum`.

# %% [markdown]
# ## Folded spectra
# {class}`Spectrum` and {class}`Spectra` objects can also be folded by collapsing the bins corresponding to the derived allele counts onto the bins corresponding to the ancestral allele counts. Basing the DFE inference on folded spectra, we have less information to work with, which is particularly noticeable when including beneficial mutations. However, folded spectra are easier to obtain, and are robust to misspecification of the ancestral state, which is often unknown. DFE inference is based on folded spectra whenever spectrum.is_folded is ``True``.

# %%
# create subplots
fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(7, 3))

# fold spectra object
spectra.fold().plot(ax=ax1)

# fold spectrum object
sfs.fold().plot(ax=ax2);
